# %% [markdown]
# # SETUP
# ---

# %% [markdown]
# ## import packages

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import scipy
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter as cntr

# %% [markdown]
# ## read data file and create data frame

# %%
imdb_raw = pd.read_csv('train.txt', delimiter= '\t', header=None)
imdb_raw.columns = ['comment', 'sentiment']

# %% [markdown]
# ## inspect data

# %%
imdb_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
# comment      1000 non-null object
# sentiment    1000 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 15.7+ KB

# %% [markdown]
# #### data frame info
#  - 1000 rows
#  - 2 columns (1 object, 1 integer)
#  - 0 NULL records

# %%
print(imdb_raw.sentiment.nunique(), imdb_raw.sentiment.unique())
print(imdb_raw.comment.nunique())
# Out:
# 2 [0 1]
# 997

# %% [markdown]
# #### data frame num unique
#  - sentiment has 2 unique values [0, 1]
#  - comment has 997 unique values (3 redundant)

# %%
imdb_raw.head()
# Out:
#                                              comment  sentiment
# 0  A very, very, very slow-moving, aimless movie ...          0
# 1  Not sure who was more lost - the flat characte...          0
# 2  Attempting artiness with black & white and cle...          0
# 3       Very little music or anything to speak of.            0
# 4  The best scene in the movie was when Gerardo i...          1

# %% [markdown]
# #### data frame head
#  - comment column appears to be String object, containing user reviews of movies in text
#  - sentiment columns contains either 0 or 1, representing negative or positive sentiment, respectively

# %% [markdown]
# # DATA CLEANING
# ---

# %% [markdown]
# ## clean comment variable
#  - strip non alpha-numeric characters and space
#  - strip leading and trailing spaces
#  - replace double space with single space

# %%
#imdb_raw.comment = imdb_raw.comment.str.replace('"','')

# strip non alpha-numeric characters
imdb_raw.comment = imdb_raw.comment.str.replace('[^a-zA-Z\s0-9\'\/]', ' ')

# strip leading and trailing spaces
imdb_raw.comment = imdb_raw.comment.str.strip()

# replace double space with single space
imdb_raw.comment = imdb_raw.comment.str.replace('  ',' ')

# replace ' out of 10' with '/10' to standardize ratings
imdb_raw.comment = imdb_raw.comment.str.replace(' out of 10','/10')

print('--- Comment variable cleaning completed ---')
# Out:
# --- Comment variable cleaning completed ---

# %% [markdown]
# # FEATURE ENGINEERING
# ---

# %% [markdown]
# ## create word lists, split by sentiment

# %%
# initialize empty lists
good_sentiment_words = []
bad_sentiment_words = []

# iterate through every row of the data frame
for row in range(len(imdb_raw.comment)):
    # iterate through every word in each row for the comment variable
    for word in imdb_raw.comment[row].split(' '):
        # filter by word length [3,12)
        if len(word) in range(3,12):
            # assign to proper sentiment list
            if imdb_raw.sentiment[row]:
                good_sentiment_words.append(word.upper())
            else:
                bad_sentiment_words.append(word.upper())

print('--- Word list creation completed ---')
print('')
print(list(set(good_sentiment_words)))
print('')
print(list(set(bad_sentiment_words)))
# Out:
# --- Word list creation completed ---
#
'HALFWAY', 'THIS', 'RESPECTING', 'OTHERWISE', 'GLASSES', 'FORCED', 'INTELLIGENT', 'PROCEEDINGS', 'OSCAR', 'PLACE', 'FINANCIAL', 'FACE', 'SAW', 'MANAGED', 'CALLS', 'HOWELL', 'WARMTH', 'SAYS', 'LIGHTING', 'ENJOY', 'CHILDHOOD', 'MASTERFUL', 'STRONG', 'SOME', 'WOULDNT', 'SUCH', 'OFFEND', 'PAR', 'DODGE', 'TWO', 'AFTER', 'THOUSAND', 'TONE', 'UNORIGINAL', 'HENCE', 'MISPLACE', 'CULT', 'FREEDOM', 'NOW', 'SEVERAL', 'TENSION', 'SATANIC', 'INVOLVED', 'EXISTENT', 'FACIAL', 'ROCHON', 'MINUTE', 'BAKERY', 'SHAMEFUL', 'NETWORK', 'DESTROY', 'PIECES', 'ROUGH', 'LATTER', 'CREATE', 'GORE', 'NET', 'JAMES', 'BEEN', 'HANDS', "IT'S", 'F/X', 'SUMMARY', "GIRL'", 'LETS', 'GEEK', 'NEXT', 'ENTIRELY', 'NATURE', 'COMPOSED', 'UNDERBITE', 'RUTHLESS', 'SPECIAL', 'BIBLE', 'ACTUALLY', 'REVERSE', 'TWISTS', 'ANGELA', 'THROUGH', 'TRIES', 'IFFY', 'READING', 'FIT', 'INCENDIARY', 'SPEW', 'RISE', "WHO'S", 'BLARE', 'HELL', 'DECENT', 'OFTEN', "'COVER", 'FEELING', '1995', "LET'S", 'FOLLOWS', 'FORGETTABLE', 'MOVES', 'SORRY', "WE'D", 'AMATEURISH', 'GERE', 'VULCAN', 'CAUSE', 'THINK', 'DISBELIEF', 'LIST', 'SHELVES', 'TODAY', "'FILM'", 'BAD', 'JONAH', 'ADRIFT', 'ASSAULTED', 'PATHETIC', 'BALLET', 'FOX', 'STANWYCK', 'YAWN', 'BOOK', "AUSTEN'S", 'AWFUL', 'POOR', 'SURPRISING', 'BLUE/GREEN', 'REASONABLE', 'LEVELS', 'AUDIENCE', 'WORTHLESS', 'RESCUE', 'EARTH', 'NEIGHBOUR', 'QUALITIES', 'PYROMANIAC', 'JIM', 'REASON', 'IMAGINE', 'BASICALLY', 'BELA', 'ONES', "STANWYCK'S", 'CONTAINING', 'USUAL', 'RITA', 'PRODUCED', 'GAVE', 'CASES', 'ENDING', '1/10', 'SIGN', 'SHORT', 'AIR', 'ESTABLISHED', 'WHAT', 'MOVEMENTS', 'FILM', 'DISPARATE', 'ZOMBIEZ', 'FRONT', 'HIGH', 'RATHER', 'WERE', 'SEASON', 'ANNIVERSARY', 'WANT', 'KNOW', 'SINCE', 'TORTURE', 'DEFINITELY', 'FASTER', 'INSULT', 'MISERABLY', 'TRANSLATE', 'AROUND', 'RESEARCHED', 'AIRED', 'SLOW', 'PURITY', 'SOAP', 'LEVEL', 'MORE', 'PACING', 'FULLY', 'MEDIOCRE', 'BO ...

# %% [markdown]
# ## create neutral word list

# %%
def intersection(lst1, lst2): 
    lst3 = [value for value in lst1 if value in lst2] 
    return lst3 

def diff_list(first, second):
        second = set(second)
        return [item for item in first if item not in second]

neutral_sentiment_words = [pair[0] for pair in cntr(intersection(good_sentiment_words, bad_sentiment_words)).most_common(30)]
#print(neutral_sentiment_words)
neutral_sentiment_words = diff_list(neutral_sentiment_words,['GOOD','GREAT','VERY','ALL','ONE','BUT','NOT'])
print('--- Neutral word list creation completed ---')
print('')
print(neutral_sentiment_words)
# Out:
# --- Neutral word list creation completed ---
#
# ['THE', 'AND', 'THIS', 'FILM', 'MOVIE', 'WAS', 'THAT', 'WITH', 'FOR', 'ARE', "IT'S", 'YOU', 'HIS', 'FROM', 'WELL', 'ABOUT', 'HAS', 'CHARACTERS', 'JUST', 'OUT', 'WHO', 'MORE', 'HAVE']

# %% [markdown]
# ## create word-pair lists, split by sentiment

# %%
from itertools import tee#, izip

def pairwise(iterable):
    "s -> (s0,s1), (s1,s2), (s2, s3), ..."
    a, b = tee(iterable)
    next(b, None)
    return zip(a, b)

# initialize empty lists
good_sentiment_word_pairs = []
bad_sentiment_word_pairs = []

# iterate through every row of the data frame
for row in range(len(imdb_raw.comment)):
    word_pair_list = list(pairwise(imdb_raw.comment[row].split()))
    #print(word_pair_list)
    #print('---')
    tmp = []
    for word_pair in word_pair_list:
        tmp.append((' '.join(word_pair)).upper())
    if imdb_raw.sentiment[row]:
        good_sentiment_word_pairs += tmp
    else:
        bad_sentiment_word_pairs += tmp

print('--- Word-pair list creation completed ---')
print('')
print(list(set(good_sentiment_word_pairs)))
print('')
print(list(set(bad_sentiment_word_pairs)))
# Out:
# --- Word-pair list creation completed ---
#
# ['IT PLAY', 'SHOT IN', 'PRODUCERS SCOT', 'CASTING THE', 'LIES A', 'A CAMERA', 'CHARACTER AGE', 'LEAVES ROOM', 'BOMBARDMENTS OF', 'EACH DO', 'THROUGH THE', 'FILM IT', 'WHERE SOMETHING', 'VERY STRONG', 'STUNNING TO', 'BERTOLUCCI BUT', 'BRILLIANT TWIST', 'SUBTLE REFERENCES', 'ARE TREMENDOUS', 'ACTING HELPS', 'UNDERSTAND WHERE', 'GRIMES AND', 'LOVE THAT', 'THAT SHOWS', 'THE SCREAM', 'A LESSER', 'HER ROOM', 'THAT IT', 'THEMSELVES NO', 'WAS SUCH', 'IS PLAYED', 'AND YOU', 'NOT BE', 'TIME WITH', 'CHOICES WITH', 'PRESENCE SHINED', 'SENTIMENT ACTUALLY', 'MICKEY MOUSE', 'WHITE AND', 'THAT HER', 'SONGS EVER', 'THOUGHT ERROL', 'ONE GALLEY', 'FI FILM', 'GETS NAKED', 'WHOLESOME APPEARANCE', 'WORD OF', 'MOVIE AS', 'AN ART', "WOMEN THERE'S", 'RUNNING THROUGH', 'EFFECTS AND', 'YET I', 'UNDERAPPRECIATED BRIAN', "I CAN'T", 'KNOWS WHAT', 'OUT SURPRISINGLY', 'THE PERFORMANCES', 'TO MONSTROUS', 'BEST SCORE', 'HAD FOR', 'ANGLE AND', 'WORK OF', 'ISSUES AT', 'ACTORS WHO', 'SHOULD BE', 'OVER AND', 'IS D
D', 'WRITING SO', 'THAT LOOKED', 'PREDICTABLE THAT', 'BY A', 'SHOULD BE', 'REALLY STUPID', 'WOULD BEGIN', 'SUSPENSE I', 'NOT QUITE', 'IS DEFINITELY', 'AT ANY', 'ME SYMPATHETIC', 'TOTALLY IMPLAUSIBLE', 'CINEMATOGRAPHY IF', 'AND MATURE', 'WAVE OF', 'HOLD YOUR', 'THAT OVERALL', 'NETWORK THAT', 'ACHIEVEMENT AS', 'NONSENSE THAT', "AREN'T IN", 'SLOW MOTION', 'NEVER REALLY', 'DISAPPOINTED BECAME', 'KEEP YOU', "YOU HAVEN'T", 'TO MENTION', 'EVERY PLOT', 'MST3K FODDER', "FILM DIDN'T", 'GO ON', 'BETWEEN TAYLOR', 'PULLING THE', 'NOT FUNNY', 'FOR GREATNESS', 'ON EARTH', 'GOOD DAY', 'NEXT MINUTE', 'MY NERVES', 'THAT JUNE', 'DIALOG CHIMP', 'CULT MOVIE', 'A FILM', 'BEEN GREAT', 'SO EMBARRASSING', 'EXCUSE FOR', 'THIS SUB', 'BE AN', 'YEAR WORKING', 'OR CONFLICT', 'ROBOTIC FACE', 'OF UNCONVINCING', 'CLICH S', 'TO MAKE', 'A PURE ...

# %% [markdown]
# ## combine word and word-pair lists

# %%
keywords_s = list(set(good_sentiment_words)) + list(set(bad_sentiment_words))
keywords = keywords_s
keywords += list(set(good_sentiment_word_pairs)) + list(set(bad_sentiment_word_pairs))
print('--- Combine word lists completed ---')
print('')
print(keywords_s)
# Out:
# --- Combine word lists completed ---
#
# ['TONS', 'PERFORMANCE', 'DISCOVERING', 'AAILIYAH', 'SISTERS', 'SOCIAL', 'SHOT', 'LEAVE', 'RUN', 'RIGHT', 'SEEING\x85', 'SIMPLY', 'THOUGH', "AMERICA'S", 'CLOSED', 'MARTIN', 'RECURRING', 'ELIAS', 'MOVIE', 'FLOWED', 'LEAVES', 'LAYERS', 'COLORFUL', 'ENTERTAINED', 'CENTURY', 'QUITE', 'WHERE', 'VALUES', 'HAVING', 'SMITH', 'WORTHY', 'SOUND', 'DEEPLY', 'RECOMMENDED', 'PRELUDE', 'WASTED', 'PUZZLE', 'BOTHERSOME', 'CAILLES', 'FIELDS', 'FRENCH', 'SIMMERING', 'BELIEVE', 'REALITY', "HOFFMAN'S", 'PARTS', 'HEELS', 'BIT', 'ORIENTED', 'SHARING', "BAILEY'S", 'BALANCE', 'TRY', 'HARD', 'UNTIL', 'TRUMBULL', 'PRESENTS', 'PART', 'TRIUMPHED', 'EVIL', 'STARLET', 'BEAR', "'TITTA", 'THEATRES', 'ENCHANTING', 'MANAGES', 'LIEUTENANT', 'TOTALLY', 'EVER', 'RACE', 'TELLY', 'EXTREMELY', 'CHARLES', 'GOVERNMENT', 'OUR', 'ACHILLE', 'THOROUGHLY', 'LIGHT', 'WHEN', 'SISTER', 'NOTEWORTHY', 'GERARDO', 'REPAIR', 'PROBLEMS', 'BLACK', 'EUROPEAN', 'FLORIDA', 'OLIVIA', 'ASPECT', 'MATR
GHTFUL', 'PROVOKING', 'SEX', 'BEHOLD', 'LATEST', 'REVEALING', 'POST', 'WEAVING', 'JACK', 'SCHILLING', '2005', 'TONGUE', 'DOMINATED', 'MINUTE', 'ARTS', 'LION', 'GHIBILI', 'GRIPPING', 'PIECES', 'CREATE', 'TYING', 'JAMES', 'BEEN', 'HANDS', "IT'S", 'SUMMARY', 'AMAZED', 'NEXT', 'ALONG', 'NUN', 'LEE', 'PAINT', 'NATURE', 'ORDEAL', 'RIOT', 'TOUCHING', 'RUTHLESS', 'RYANS', 'HEROINE', 'VOCAL', 'GRANTED', 'KEIRA', 'THRILLERS', 'CREDITS', 'SARCOPHAGE', 'BOYLE', 'SIBLING', 'SPECIAL', 'ACTUALLY', 'GADGET', 'JULIAN', 'DREAMS', 'IMPERIAL', 'TITLE', 'TELEPHONE', 'SIGNIFICANT', 'GLORIOUSLY', 'ASTRONAUT', 'THROUGH', 'HUGO', 'PREPARED', 'READING', 'FIT', 'DUSTIN', 'NERVOUS', 'HAPPY', 'HOOT', 'NEVSKY', 'CONTINUALLY', 'CANDLE', "POET'S", 'UNDERSTATED', 'FLAMING', 'DECENT', 'BREAKING', 'OFTEN', 'FEELING', 'FAMED', 'SENSIBILITY', "HITCHCOCK'S", 'THINK', 'SUITED', 'LIST', 'INTEGRAL', 'DARREN', 'TODAY', 'BAD', 'DREAM', 'JONAH', 'HUSTON', 'STANWYCK', "RICE'S", 'BOOK', 'FLASHBACKS', 'PROMOTE', "ELSE'S", 'SURPRISING', 'JAY', 'DESPERATION', 'LEVELS', 'PALANCE', 'AUDIENCE', ' ...

# %% [markdown]
# ## add keywords to data frame as feature columns

# %%
for key in keywords:   
    try:
        imdb_raw[str(key)] = imdb_raw.comment.str.contains(str(key), case=False)
    except:
        print(key)

print('--- Initial feature creation completed ---')
# Out:
# --- Initial feature creation completed ---

# %% [markdown]
# ### additional feature BRILL
#  - combines 'BRILLIANT' and 'BRILLIANCE' to strengthen positive connotation

# %%
contains_list = ['BRILLIANT','BRILLIANCE']
imdb_raw['BRILL'] = imdb_raw.comment.str.contains('|'.join(contains_list),case=False)

print('--- Additional feature BRILL added --')
# Out:
# --- Additional feature BRILL added --

# %% [markdown]
# ### additional feature GOOD_RATING
#  - combines ratings 8/10, 9/10, 10/10 to strengthen positive connotation

# %%
contains_list = ['10/10','9/10', '8/10']
imdb_raw['GOOD_RATING'] = imdb_raw.comment.str.contains('|'.join(contains_list), case=False)

print('--- Additional feature GOOD_RATING added --')
# Out:
# --- Additional feature GOOD_RATING added --

# %%
imdb_raw.head()
# Out:
#                                              comment  sentiment   TONS  \
# 0  A very very very slow moving aimless movie abo...          0  False
# 1  Not sure who was more lost  the flat character...          0  False
# 2  Attempting artiness with black  white and clev...          0  False
# 3          Very little music or anything to speak of          0  False
# 4  The best scene in the movie was when Gerardo i...          1  False
#
#    PERFORMANCE  DISCOVERING  AAILIYAH  SISTERS  SOCIAL   SHOT  LEAVE  ...  \
# 0        False        False     False    False   False  False  False  ...
# 1        False        False     False    False   False  False  False  ...
# 2        False        False     False    False   False  False  False  ...
# 3        False        False     False    False   False  False  False  ...
# 4        False        False     False    False   False  False  False  ...
#
#    A TERRIBLE  GET THAT  BY PAUL  BAKERY ASSISTANT  THAT AS  IN SUCH  \
# 0       False     False    False             False    False    False
# 1       False     False    False             False    False    False
# 2       False     False    False             False    False    False
# 3       False     False    False             False    False    False
# 4       False     False    False             False    False    False
#
#    AND CERTAINLY  THING YOU  BRILL  GOOD_RATING
# 0          False      False  False        False
# 1          False      False  False        False
# 2          False      False  False        False
# 3          False      False  False        False
# 4          False      False  False        False
#
# [5 rows x 12673 columns]

# %%
#imdb_raw.corrwith(imdb_raw.sentiment).sort_values()

# %% [markdown]
# ### find least correlating features

# %% [markdown]
# #### correlate each feature with sentiment

# %%
# correlate features with sentiment, convert result to data frame and reset index
sentiment_corr = imdb_raw.corrwith(imdb_raw.sentiment).sort_values().to_frame().reset_index()

# add column names
sentiment_corr.columns = ['feature', 'correlation']

# view new data frame
sentiment_corr
# Out:
#                   feature  correlation
# 0                     BAD    -0.223922
# 1                  STUPID    -0.123404
# 2                   WASTE    -0.122713
# 3                    EVEN    -0.119648
# 4                   AWFUL    -0.119159
# 5                   WOULD    -0.117224
# 6                    PLOT    -0.109109
# 7                     NOT    -0.108625
# 8                   WORST    -0.105463
# 9                  DIDN'T    -0.104614
# 10                    LOT    -0.104605
# 11              THE WORST    -0.100504
# 12                  BAD I    -0.100504
# 13               EVER SEE    -0.097110
# 14                    WAS    -0.096478
# 15                 SO BAD    -0.095298
# 16                  START    -0.095298
# 17                   HOUR    -0.095298
# 18              EVER SEEN    -0.091840
# 19               TERRIBLE    -0.091840
# 20                  CHEAP    -0.089803
# 21                   ONLY    -0.089389
# 22                   SUCK    -0.086288
# 23                 AT ALL    -0.086288
# 24                  WORSE    -0.086288
# 25                  IS NO    -0.085093
# 26                 SUCKED    -0.083960
# 27                   POOR    -0.083960
# 28               WASTE OF    -0.083960
# 29                   BORE    -0.083960
# ...                   ...          ...
# 12642            THIS BAD          NaN
# 12643        AMERICANS IT          NaN
# 12644             WAS HOW          NaN
# 12645            SAY IT'S          NaN
# 12646        TENSION SOME          NaN
# 12647            ETC IT'S          NaN
# 12648       REPERTORY THE          NaN
# 12649          FORMER THE          NaN
# 12650       SLEEP FOREVER          NaN
# 12651            STAR BUT          NaN
# 12652    CAMERAWORK AGAIN          NaN
# 12653           WELL TALK          NaN
# 12654     SUCKS BASICALLY          NaN
# 12655         BLACK WHITE          NaN
# 12656            1/10 AND          NaN
# 12657          AGAIN THIS          NaN
# 12658          AWFUL WITH          NaN
# 12659           PLOT WELL          NaN
# 12660          ENERGY BUT          NaN
# 12661            BAD WELL          NaN
# 12662           LAME TAKE          NaN
# 12663          CHEESY NOT          NaN
# 12664          MEANING IF          NaN
# 12665             LEAST I          NaN
# 12666      ARMAGEDDON AND          NaN
# 12667          SHORT THIS          NaN
# 12668        KIDS PULLING          NaN
# 12669          MAYBE POOR          NaN
# 12670         GLASSES THE          NaN
# 12671  EXAGGERATING EVERY          NaN
#
# [12672 rows x 2 columns]

# %% [markdown]
# #### filter correlation data frame  to least correlating features

# %%
low_corr_features = sentiment_corr[(sentiment_corr['correlation'] < 0.001) & (sentiment_corr['correlation'] > -0.001)]
low_corr_features
# Out:
#           feature   correlation
# 5462     FILM AND -1.032130e-16
# 5463         FEEL -1.001645e-16
# 5464     AND THAT -9.092890e-17
# 5465          GOT -6.803623e-17
# 5466        LEVEL -6.792712e-17
# 5467       LIKE A -5.575191e-17
# 5468       MOMENT -4.384714e-17
# 5469       I HAVE -2.929338e-17
# 5470        SCENE -2.817994e-17
# 5471        ARE A -2.740348e-17
# 5472         FACT -1.841097e-17
# 5473         MAIN -1.617312e-17
# 5474      SOME OF -1.473551e-17
# 5475         VERY -1.157592e-17
# 5476   UNDERSTAND -6.694897e-18
# 5477       SUCH A -6.694897e-18
# 5478         REAL -5.365943e-18
# 5479         DOES -4.758099e-18
# 5480          GET -3.399350e-18
# 5481         KEEP -2.875222e-18
# 5482       CAMERA -2.549066e-18
# 5483         SUCH -2.039253e-18
# 5484      AMERICA -1.797014e-18
# 5485    DRAMA AND -1.319204e-18
# 5486    GENERALLY -1.319204e-18
# 5487         CARE -1.115816e-18
# 5488         FORT -1.019627e-18
# 5489       BEFORE -7.188055e-19
# 5490        VIDEO -6.212551e-19
# 5491     TO VIDEO -6.212551e-19
# ...           ...           ...
# 6053  WAS NOTHING  9.318827e-19
# 6054  THE THEATRE  9.318827e-19
# 6055         IT A  1.019627e-18
# 6056       REVIEW  1.078208e-18
# 6057        TO ME  1.078208e-18
# 6058       VISUAL  1.078208e-18
# 6059        SONGS  1.319204e-18
# 6060         SETS  1.319204e-18
# 6061       5 YEAR  1.319204e-18
# 6062     MOVIE IS  1.450807e-18
# 6063       AND IT  1.529440e-18
# 6064          SET  1.673724e-18
# 6065      MOVIE A  1.769631e-18
# 6066       TALENT  2.156417e-18
# 6067          FEW  2.156417e-18
# 6068       LOT OF  2.515819e-18
# 6069          MAD  2.691895e-18
# 6070     RELATION  2.875222e-18
# 6071          ERA  3.116179e-18
# 6072         SIDE  3.340244e-18
# 6073         NEED  3.594028e-18
# 6074       YOU DO  3.953430e-18
# 6075     THIS ONE  6.117759e-18
# 6076        ROUND  8.368621e-18
# 6077   THIS MOVIE  1.305392e-17
# 6078          WAY  1.451680e-17
# 6079        ME TO  1.940775e-17
# 6080         LEAD  2.515819e-17
# 6081         CAME  5.052119e-17
# 6082   BELIEVABLE  6.415943e-17
#
# [621 rows x 2 columns]

# %% [markdown]
# # EXECUTE NAIVE BAYES

# %% [markdown]
# ## generate data and target inputs to the model

# %%
# save each iteration of work into a separate variable
data1 = imdb_raw[keywords_s]
data2 = imdb_raw[keywords]
data3 = imdb_raw[keywords_s + ['BRILL'] + ['GOOD_RATING']] #4.5% inaccuracy
data4 = imdb_raw[diff_list(keywords_s + ['BRILL'] + ['GOOD_RATING'],neutral_sentiment_words)] # 3.6% inaccuracy
data5 = imdb_raw[diff_list(keywords_s + ['BRILL'] + ['GOOD_RATING'],low_corr_features.feature.to_list() + neutral_sentiment_words)] # 3.6% inaccuracy

# collect iterations of work into a list to iterate through
data_list = [data1, data2, data3, data4, data5]

# define target variable
target = imdb_raw['sentiment']

# %% [markdown]
# ## execute Bernoulli NB model

# %%
# import BernoulliNB
from sklearn.naive_bayes import BernoulliNB

# iterate through data iterations
for data in data_list:
    nb = BernoulliNB() # Instantiate our model and store it in a new variable.
    nb.fit(data, target) # Fit our model to the data.
    y_pred = nb.predict(data) # Classify, storing the result in a new variable.
    print(f'[BernoulliNB] mislabelled:\t {(target != y_pred).sum()}/{data.shape[0]}; {(target != y_pred).sum()/target.count()*100:.4f}%')
# Out:
# [BernoulliNB] mislabelled:	 53/1000; 5.3000%
# [BernoulliNB] mislabelled:	 53/1000; 5.3000%
# [BernoulliNB] mislabelled:	 45/1000; 4.5000%
# [BernoulliNB] mislabelled:	 36/1000; 3.6000%
# [BernoulliNB] mislabelled:	 36/1000; 3.6000%

# %% [markdown]
# ## execute Gaussian NB model

# %%
# import GaussianNB
from sklearn.naive_bayes import GaussianNB

# iterate through data iterations
for data in data_list:
    nb = GaussianNB() # Instantiate our model and store it in a new variable.
    nb.fit(data, target) # Fit our model to the data.
    y_pred = nb.predict(data) # Classify, storing the result in a new variable.
    print(f'[GaussianNB] mislabelled:\t {(target != y_pred).sum()}/{data.shape[0]}; {(target != y_pred).sum()/target.count()*100:.4f}%')
# Out:
# [GaussianNB] mislabelled:	 1/1000; 0.1000%
# [GaussianNB] mislabelled:	 1/1000; 0.1000%
# [GaussianNB] mislabelled:	 1/1000; 0.1000%
# [GaussianNB] mislabelled:	 1/1000; 0.1000%
# [GaussianNB] mislabelled:	 1/1000; 0.1000%

# %% [markdown]
# ## execute Multinomial NB model

# %%
# import MultinomialNB
from sklearn.naive_bayes import MultinomialNB

# iterate through data iterations
for data in data_list:
    nb = MultinomialNB() # Instantiate our model and store it in a new variable.
    nb.fit(data, target) # Fit our model to the data.
    y_pred = nb.predict(data) # Classify, storing the result in a new variable.
    print(f'[MultinomialNB] mislabelled:\t {(target != y_pred).sum()}/{data.shape[0]}; {(target != y_pred).sum()/target.count()*100:.4f}%')
# Out:
# [MultinomialNB] mislabelled:	 21/1000; 2.1000%
# [MultinomialNB] mislabelled:	 21/1000; 2.1000%
# [MultinomialNB] mislabelled:	 21/1000; 2.1000%
# [MultinomialNB] mislabelled:	 19/1000; 1.9000%
# [MultinomialNB] mislabelled:	 20/1000; 2.0000%

# %% [markdown]
# ## execute Complement NB model

# %%
# import ComplementNB
from sklearn.naive_bayes import ComplementNB

# iterate through data iterations
for data in data_list:
    nb = ComplementNB() # Instantiate our model and store it in a new variable.
    nb.fit(data, target) # Fit our model to the data.
    y_pred = nb.predict(data) # Classify, storing the result in a new variable.
    print(f'[ComplementNB] mislabelled:\t {(target != y_pred).sum()}/{data.shape[0]}; {(target != y_pred).sum()/target.count()*100:.4f}%')
# Out:
# [ComplementNB] mislabelled:	 21/1000; 2.1000%
# [ComplementNB] mislabelled:	 21/1000; 2.1000%
# [ComplementNB] mislabelled:	 21/1000; 2.1000%
# [ComplementNB] mislabelled:	 19/1000; 1.9000%
# [ComplementNB] mislabelled:	 20/1000; 2.0000%

# %% [markdown]
# ## view Mislabelled records

# %% [markdown]
# ### Trained=1 (good sentiment), Predicted=0 (bad sentiment)

# %%
print('Trained Good, Predicted Bad')
print('count\tindex\ttrain\tpred\tcomment')
print('------------------------------------')
cnt = 0
for i in range(len(target)):
    if target[i] != y_pred[i]:
        if target[i]:
            cnt += 1
            print(cnt,'\t', i,'\t', target[i],'\t', y_pred[i],'\t', imdb_raw.comment[i])
# Out:
# Trained Good, Predicted Bad
# count	index	train	pred	comment
# ------------------------------------
# 1 	 31 	 1 	 0 	 Waste your money on this game
# 2 	 32 	 1 	 0 	 This is the kind of money that is wasted properly
# 3 	 50 	 1 	 0 	 I'm glad the film didn't go for the most obvious choice as a lesser film certainly would have
# 4 	 57 	 1 	 0 	 Totally believable
# 5 	 100 	 1 	 0 	 I don't think you will be disappointed
# 6 	 279 	 1 	 0 	 There is a lot of beautiful places
# 7 	 296 	 1 	 0 	 Three of the most visually appealing movies i've ever seen
# 8 	 443 	 1 	 0 	 The last 15 minutes of movie are also not bad as well
# 9 	 492 	 1 	 0 	 But this movie really got to me
# 10 	 619 	 1 	 0 	 Don't miss it
# 11 	 640 	 1 	 0 	 But it is entertaining nonetheless
# 12 	 751 	 1 	 0 	 But I thought his acting was skilled
# 13 	 794 	 1 	 0 	 Predictable but not a bad watch
# 14 	 989 	 1 	 0 	 Anyway the plot flowed smoothly and the male bonding scenes were a hoot

# %% [markdown]
# ### Trained=0 (bad sentiment), Predicted=1 (good sentiment)

# %%
print('Trained Bad, Predicted Good')
print('count\tindex\ttrain\tpred\comment')
print('------------------------------------')
cnt = 0
for i in range(len(target)):
    if target[i] != y_pred[i]:
        if not target[i]:
            cnt += 1
            print(cnt,'\t', i,'\t', target[i],'\t', y_pred[i],'\t', imdb_raw.comment[i])
# Out:
# Trained Bad, Predicted Good
# count	index	train	pred\comment
# ------------------------------------
# 1 	 26 	 0 	 1 	 Graphics is far from the best part of the game
# 2 	 133 	 0 	 1 	 All in all a great disappointment
# 3 	 185 	 0 	 1 	 Highly unrecommended
# 4 	 199 	 0 	 1 	 The film is way too long
# 5 	 222 	 0 	 1 	 Mishima is extremely uninteresting
# 6 	 602 	 0 	 1 	 I saw this movie and I thought this is a stupid movie

# %% [markdown]
# ## view all records

# %%
print('count\tindex\ttrain\tpred\tcomment')
print('------------------------------------')
cnt = 0
for i in range(len(target)):
    print(cnt,'\t', i,'\t', target[i],'\t', y_pred[i],'\t', imdb_raw.comment[i])
# Out:
# count	index	train	pred	comment
# ------------------------------------
# 0 	 0 	 0 	 0 	 A very very very slow moving aimless movie about a distressed drifting young man
# 0 	 1 	 0 	 0 	 Not sure who was more lost  the flat characters or the audience nearly half of whom walked out
# 0 	 2 	 0 	 0 	 Attempting artiness with black  white and clever camera angles the movie disappointed  became even more ridiculous  as the acting was poor and the plot and lines almost non existent
# 0 	 3 	 0 	 0 	 Very little music or anything to speak of
# 0 	 4 	 1 	 1 	 The best scene in the movie was when Gerardo is trying to find a song that keeps running through his head
# 0 	 5 	 0 	 0 	 The rest of the movie lacks art charm meaning  If it's about emptiness it works I guess because it's empty
# 0 	 6 	 0 	 0 	 Wasted two hours
# 0 	 7 	 1 	 1 	 Saw the movie today and thought it was a good effort good messages for kids
# 0 	 8 	 0 	 0 	 A bit predictable
# 0 	 9 	 1 	 1 	 Loved the casting of Jimmy Buffet as the science teacher
# 0 	 10 	 1 	 1 	 And those baby owls were adorable
# 0 	 11 	 1 	 1 	 The movie showed a lot of Florida at it's best made it look very appealing
# 0 	 12 	 1 	 1 	 The Songs Were The Best And The Muppets Were So Hilarious
# 0 	 13 	 1 	 1 	 It Was So Cool
# 0 	 14 	 1 	 1 	 This is a very right on case movie that delivers everything almost right in your face
# 0 	 15 	 0 	 0 	 It had some average acting from the main person and it was a low budget as you clearly can see
# 0 	 16 	 1 	 1 	 This review is long overdue since I consider A Tale of Two Sisters to be the single greatest film ever made
# 0 	 17 	 1 	 1 	 I'll put this gem up against any movie in terms of screenplay cinematography acting post production editing directing or any other aspect of film making
# 0 	 18 	 1 	 1 	 It's practically perfect in all of them  a true masterpiece in a sea of faux masterpieces
# 0 	 19 	 1 	 1 	 The structure of this film is easily the most tightly constructed in the history of cinema
# 0 	 20 	 1 	 1 	 I can think of no other film where something vitally important occurs every other minute
# 0 	 21 	 1 	 1 	 In other words the content level of this film is enough to easily fill a dozen other films
# 0 	 22 	 1 	 1 	 How can anyone in their right mind ask for anything more from a movie than this
# 0 	 23 	 1 	 1 	 It's quite simply the highest most superlative form of cinema imaginable
# 0 	 24 	 1 	 1 	 Yes this film does require a rather significant amount of puzzle solving but the pieces fit together to create a beautiful picture
# 0 	 25 	 0 	 0 	 This short film certainly pulls no punches
# 0 	 26 	 0 	 1 	 Graphics is far from the best part of the game
# 0 	 27 	 1 	 1 	 This is the number one best TH game in the series
# 0 	 28 	 1 	 1 	 It deserves strong love
# 0 	 29 	 1 	 1 	 It is an insane game
# 0 	 30 	 1 	 1 	 There are massive levels massive unlockable characters  it's just a massive game
# 0 	 31 	 1 	 0 	 Waste your money on this game
# 0 	 32 	 1 	 0 	 This is the kind of money that is wasted properly
# 0 	 33 	 1 	 1 	 Actually the graphics were good at the time
# 0 	 34 	 0 	 0 	 Today the graphics are crap
# 0 	 35 	 1 	 1 	 As they say in Canada This is the fun game aye
# 0 	 36 	 1 	 1 	 This game rocks
# 0 	 37 	 1 	 1 	 Buy it play it enjoy it love it
# 0 	 38 	 1 	 1 	 It's PURE BRILLIANCE
# 0 	 39 	 0 	 0 	 This was a flick doomed from its conception
# 0 	 40 	 0 	 0 	 The very idea of it was lame  take a minor character from a mediocre PG 13 film and make a complete non sequel while changing its tone to a PG rated family movie
# 0 	 41 	 0 	 0 	 I wasn't the least bit interested
# 0 	 42 	 0 	 0 	 Not only did it only confirm that the film would be unfunny and generic but it also managed to give away the ENTIRE movie and I'm not exaggerating  every moment every plot point every joke is told in the trailer
# 0 	 43 	 0 	 0 	 But it's just not funny
# 0 	 44 	 0 	 0 	 But even the talented Carrell can't save this
# 0 	 45 	 0 	 0 	 His co stars don't fare much better with people like Morgan Freeman Jonah Hill and Ed Helms just wasted
# 0 	 46 	 0 	 0 	 The story itself is just predictable and lazy
# 0 	 47 	 0 	 0 	 The only real effects work is the presence of all the animals and the integration of those into the scenes is some of the worst and most obvious blue/green screen work I've ever seen
# 0 	 48 	 0 	 0 	 But whatever it was that cost them so much it didn't translate to quality that's for sure
# 0 	 49 	 1 	 1 	 The film succeeds despite or perhaps because of an obviously meagre budget
# 0 	 50 	 1 	 0 	 I'm glad the film didn't go for the most obvious choice as a lesser film certainly would have
# 0 	 51 	 1 	 1 	 In addition to having one of the most lovely songs ever written French Cancan also boasts one of the cutest leading ladies ever to grace the screen
# 0 	 52 	 1 	 1 	 It's hard not to fall head over heels in love with that girl
# 0 	 53 	 0 	 0 	 On the negative it's insipid enough to cause regret for another 2 hours of life wasted in front of the screen
# 0 	 54 	 0 	 0 	 Long whiny and pointless
# 0 	 55 	 0 	 0 	 But I recommend waiting for their future efforts let this one go
# 0 	 56 	 1 	 1 	 Excellent cast story line performances
# 0 	 57 	 1 	 0 	 Totally believable
# 0 	 58 	 1 	 1 	 Anne Heche was utterly convincing
# 0 	 59 	 1 	 1 	 Sam Shepard's portrayal of a gung ho Marine was sobering
# 0 	 60 	 1 	 1 	 I sat riveted to the TV screen
# 0 	 61 	 1 	 1 	 All in all I give this one a resounding 9/10
# 0 	 62 	 1 	 1 	 I do think Tom Hanks is a good actor
# 0 	 63 	 1 	 1 	 I enjoyed reading this book to my children when they were little
# 0 	 64 	 0 	 0 	 I was very disappointed in the movie
# 0 	 65 	 0 	 0 	 One character is totally annoying with a voice that gives me the feeling of fingernails on a chalkboard
# 0 	 66 	 0 	 0 	 There is a totally unnecessary train/roller coaster scene
# 0 	 67 	 0 	 0 	 There was absolutely no warmth or charm to these scenes or characters
# 0 	 68 	 0 	 0 	 This movie totally grates on my nerves
# 0 	 69 	 0 	 0 	 The performances are not improved by improvisation because the actors now have twice as much to worry about not only whether they're delivering the line well but whether the line itself is any good
# 0 	 70 	 0 	 0 	 And quite honestly often its not very good
# 0 	 71 	 0 	 0 	 Often the dialogue doesn't really follow from one line to another or fit the surroundings
# 0 	 72 	 0 	 0 	 It crackles with an unpredictable youthful energy  but honestly i found it hard to follow and concentrate on it meanders so badly
# 0 	 73 	 1 	 1 	 There are some generally great things in it
# 0 	 74 	 0 	 0 	 I wouldn't say they're worth 2 hours of your time though
# 0 	 75 	 1 	 1 	 The suspense builders were good  just cross the line from G to PG
# 0 	 76 	 1 	 1 	 I especially liked the non cliche choices with the parents in other movies I could predict the dialog verbatim but the writing in this movie made better selections
# 0 	 77 	 1 	 1 	 If you want a movie that's not gross but gives you some chills this is a great choice
# 0 	 78 	 1 	 1 	 Alexander Nevsky is a great film
# 0 	 79 	 1 	 1 	 He is an amazing film artist one of the most important whoever lived
# 0 	 80 	 0 	 0 	 I'm glad this pretentious piece of s  didn't do as planned by the Dodge stratus Big Shots  It's gonna help movie makers who aren't in the very restrained movie business of Qu bec
# 0 	 81 	 1 	 1 	 This if the first movie I've given a 10 to in years
# 0 	 82 	 1 	 1 	 If there was ever a movie that needed word of mouth to promote this is it
# 0 	 83 	 1 	 1 	 Overall the film is interesting and thought provoking
# 0 	 84 	 1 	 1 	 Plus it was well paced and suited its relatively short run time
# 0 	 85 	 1 	 1 	 Give this one a look
# 0 	 86 	 1 	 1 	 I gave it a 10
# 0 	 87 	 1 	 1 	 The Wind and the Lion is well written and superbly acted
# 0 	 88 	 1 	 1 	 It is a true classic
# 0 	 89 	 1 	 1 	 It actually turned out to be pretty decent as far as B list horror/suspense films go
# 0 	 90 	 1 	 1 	 Definitely worth checking out
# 0 	 91 	 0 	 0 	 The problem was the script
# 0 	 92 	 0 	 0 	 It was horrendous
# 0 	 93 	 0 	 0 	 There was NOTHING believable about it at all
# 0 	 94 	 0 	 0 	 The only suspense I was feeling was the frustration at just how retarded the girls were
# 0 	 95 	 1 	 1 	 MANNA FROM HEAVEN is a terrific film that is both predictable and unpredictable at the same time
# 0 	 96 	 1 	 1 	 The scenes are often funny and occasionally touching as the characters evaluate their lives and where they are going
# 0 	 97 	 1 	 1 	 The cast of veteran actors are more than just a nostalgia trip
# 0 	 98 	 1 	 1 	 Ursula Burton's portrayal of the nun is both touching and funny at the same time with out making fun of nuns or the church
# 0 	 99 	 1 	 1 	 If you are looking for a movie with a terrific cast some good music including a Shirley Jones rendition of The Way You Look Tonight  and an uplifting ending give this one a try
# 0 	 100 	 1 	 0 	 I don't think you will be disappointed
# 0 	 101 	 0 	 0 	 Frankly after Cotton club and Unfaithful it was kind of embarrassing to watch Lane and Gere in this film because it is BAD
# 0 	 102 	 0 	 0 	 The acting was bad the dialogs were extremely shallow and insincere
# 0 	 103 	 0 	 0 	 It was too predictable even for a chick flick
# 0 	 104 	 0 	 0 	 Too politically correct
# 0 	 105 	 0 	 0 	 Very disappointing
# 0 	 106 	 1 	 1 	 The only thing really worth watching was the scenery and the house because it is beautiful
# 0 	 107 	 0 	 0 	 I love Lane but I've never seen her in a movie this lousy
# 0 	 108 	 0 	 0 	 An hour and a half I wish I could bring back
# 0 	 109 	 1 	 1 	 But in terms of the writing it's very fresh and bold
# 0 	 110 	 1 	 1 	 The acting helps the writing along very well maybe the idiot savant sister could have been played better  and it is a real joy to watch
# 0 	 111 	 0 	 0 	 The directing and the cinematography aren't quite as good
# 0 	 112 	 0 	 0 	 The movie was so boring that I sometimes found myself occupied peaking in the paper instead of watching never happened during a Columbo movie before
# 0 	 113 	 0 	 0 	 and sometimes it was so embarrassing that I had to look away
# 0 	 114 	 0 	 0 	 The directing seems too pretentious
# 0 	 115 	 0 	 0 	 The scenes with the oh so mature neighbour girl are a misplace
# 0 	 116 	 0 	 0 	 And generally the lines and plot is weaker than the average episode
# 0 	 117 	 0 	 0 	 Then scene where they debated whether or not to sack the trumpeter who falsely was accused for the murder is pure horror really stupid
# 0 	 118 	 1 	 1 	 Some applause should be given to the prelude however
# 0 	 119 	 1 	 1 	 I really liked that
# 0 	 120 	 1 	 1 	 A great film by a great director
# 0 	 121 	 1 	 1 	 The movie had you on the edge of your seat and made you somewhat afraid to go to your car at the end of the night
# 0 	 122 	 1 	 1 	 The music in the film is really nice too
# 0 	 123 	 1 	 1 	 I'd advise anyone to go and see it
# 0 	 124 	 1 	 1 	 Brilliant
# 0 	 125 	 1 	 1 	 10/10
# 0 	 126 	 1 	 1 	 I liked this movie way too much
# 0 	 127 	 0 	 0 	 My only problem is I thought the actor playing the villain was a low rent Michael Ironside
# 0 	 128 	 1 	 1 	 It rocked my world and is certainly a must see for anyone with no social or physical outlets
# 0 	 129 	 0 	 0 	 However this didn't make up for the fact that overall this was a tremendously boring movie
# 0 	 130 	 0 	 0 	 There was NO chemistry between Ben Affleck and Sandra Bullock in this film and I couldn't understand why he would consider even leaving his wife to be for this chick that he supposedly was knocked out by
# 0 	 131 	 0 	 0 	 There were several moments in the movie that just didn't need to be there and were excruciatingly slow moving
# 0 	 132 	 0 	 0 	 This was a poor remake of My Best Friends Wedding
# 0 	 133 	 0 	 1 	 All in all a great disappointment
# 0 	 134 	 0 	 0 	 I cannot believe that the actors agreed to do this film
# 0 	 135 	 0 	 0 	 I could not stand to even watch it for very long for fear of losing I Q
# 0 	 136 	 0 	 0 	 I guess that nobody at the network that aired this dribble watched it before putting it on
# 0 	 137 	 0 	 0 	 IMDB ratings only go as low 1 for awful it's time to get some negative numbers in there for cases such as these
# 0 	 138 	 0 	 0 	 I saw Mirrormask last night and it was an unsatisfactory experience
# 0 	 139 	 0 	 0 	 Unfortunately inexperience of direction meant that scene after scene passed with little in the way of dramatic tension or conflict
# 0 	 140 	 0 	 0 	 These are the central themes of the film and they are handled ineptly stereotypically and with no depth of imagination
# 0 	 141 	 0 	 0 	 All the pretty pictures in the world cannot make up for a piece of work that is flawed at the core
# 0 	 142 	 0 	 0 	 It is an hour and half waste of time following a bunch of very pretty high schoolers whine and cry about life
# 0 	 143 	 0 	 0 	 You can't relate with them hell you barely can understand them
# 0 	 144 	 1 	 1 	 This is definitely a cult classic well worth viewing and sharing with others
# 0 	 145 	 0 	 0 	 This movie is a pure disaster the story is stupid and the editing is the worst I have seen it confuses you incredibly
# 0 	 146 	 0 	 0 	 The fish is badly made and some of its underwater shots are repeated a thousand times in the film
# 0 	 147 	 0 	 0 	 A truly truly bad film
# 0 	 148 	 0 	 0 	 The acting is terrible and the writing is worse
# 0 	 149 	 0 	 0 	 The only possible way this movie could be redeemed would be as MST3K fodder
# 0 	 150 	 0 	 0 	 I paid too much
# 0 	 151 	 1 	 1 	 Also it's a real treat to see Anthony Quinn playing Crazy Horse
# 0 	 152 	 0 	 0 	 It was so BORING
# 0 	 153 	 0 	 0 	 No plot whatsoever
# 0 	 154 	 0 	 0 	 Again no plot at all
# 0 	 155 	 0 	 0 	 Horrible
# 0 	 156 	 0 	 0 	 Worst hour and a half of my life Oh my gosh
# 0 	 157 	 0 	 0 	 I had to walk out of the theatre for a few minutes just to get some relief
# 0 	 158 	 0 	 0 	 I hate movies like that
# 0 	 159 	 0 	 0 	 Yeah the movie pretty much sucked
# 0 	 160 	 0 	 0 	 THERE IS NO PLOT OR STORYLINE
# 0 	 161 	 0 	 0 	 If you do go see this movie bring a pillow or a girlfriend/boyfriend to keep you occupied through out
# 0 	 162 	 0 	 0 	 Awful
# 0 	 163 	 0 	 0 	 I don't think I've ever gone to a movie and disliked it as much
# 0 	 164 	 0 	 0 	 It was a good thing that the tickets only cost five dollars because I would be mad if I'd have paid 7 50 to see this crap
# 0 	 165 	 0 	 0 	 NOBODY identifies with these characters because they're all cardboard cutouts and stereotypes or predictably reverse stereotypes
# 0 	 166 	 0 	 0 	 This is a bad film with bad writing and good actors  an ugly cartoon crafted by Paul Haggis for people who can't handle anything but the bold strokes in storytelling  a picture painted with crayons
# 0 	 167 	 0 	 0 	 Crash is a depressing little nothing that provokes emotion but teaches you nothing if you already know racism and prejudice are bad things
# 0 	 168 	 1 	 1 	 Still I do like this movie for it's empowerment of women there's not enough movies out there like this one
# 0 	 169 	 0 	 0 	 Your brain will attempt to shut down as part of a primal impulse of self preservation
# 0 	 170 	 0 	 0 	 I was left shattered from the experience of watching this 'film' and I took a good two hours to fully recover
# 0 	 171 	 0 	 0 	 This movie now joins Revenge of the Boogeyman and Zombiez as part of the hellish trinity of horror films
# 0 	 172 	 0 	 0 	 I certainly do not mean this distinction in a good way
# 0 	 173 	 0 	 0 	 I mean this in a terrible way
# 0 	 174 	 0 	 0 	 This film has no redeeming features
# 0 	 175 	 0 	 0 	 Everything is appalling
# 0 	 176 	 0 	 0 	 Artless camera work endlessly presents us with the ugliest setting imaginable i e
# 0 	 177 	 0 	 0 	 The story is beyond stupid
# 0 	 178 	 0 	 0 	 The script iswas there a script
# 0 	 179 	 0 	 0 	 The kids are annoying
# 0 	 180 	 0 	 0 	 The lead man is charisma free
# 0 	 181 	 0 	 0 	 Utterly without merit on any level this is akin to torture
# 0 	 182 	 0 	 0 	 I'll even say it again  this is torture
# 0 	 183 	 0 	 0 	 Maybe there would be a reasonable explanation for this atrocity
# 0 	 184 	 0 	 0 	 Not a pleasant voyage of self discovery
# 0 	 185 	 0 	 1 	 Highly unrecommended
# 0 	 186 	 0 	 0 	 If this premise sound stupid that's because it is
# 0 	 187 	 0 	 0 	 Yes it's that bad
# 0 	 188 	 0 	 0 	 Nothing at all to recommend
# 0 	 189 	 1 	 1 	 An excellent performance from Ms
# 0 	 190 	 1 	 1 	 Garbo who showed right off the bat that her talents could carry over from the silent era I wanted to see some of her silent work but Netflix doesn't seem to be stocking them
# 0 	 191 	 1 	 1 	 It's also great to see that renowned silent screenwriter Frances Marion hasn't missed a step going from silent to sound
# 0 	 192 	 0 	 0 	 This movie suffered because of the writing it needed more suspense
# 0 	 193 	 0 	 0 	 There were too many close ups
# 0 	 194 	 0 	 0 	 But other than that the movie seemed to drag and the heroes didn't really work for their freedom
# 0 	 195 	 0 	 0 	 But this movie is definitely a below average rent
# 0 	 196 	 1 	 1 	 You'll love it
# 0 	 197 	 0 	 0 	 This movie is BAD
# 0 	 198 	 0 	 0 	 So bad
# 0 	 199 	 0 	 1 	 The film is way too long
# 0 	 200 	 0 	 0 	 This is definitely one of the bad ones
# 0 	 201 	 1 	 1 	 The movie I received was a great quality film for it's age
# 0 	 202 	 1 	 1 	 John Wayne did an incredible job for being so young in the movie industry
# 0 	 203 	 1 	 1 	 His on screen presence shined thought even though there were other senior actors on the screen with him
# 0 	 204 	 1 	 1 	 I think that it is a must see older John Wayne film
# 0 	 205 	 0 	 0 	 I really don't see how anyone could enjoy this movie
# 0 	 206 	 0 	 0 	 I don't think I've ever seen a movie half as boring as this self indulgent piece of junk
# 0 	 207 	 0 	 0 	 It probably would have been better if the director hadn't spent most of the movie showcasing his own art work which really isn't that noteworthy
# 0 	 208 	 0 	 0 	 Another thing I didn't really like is when a character got punched in the face a gallon of blood would spew forth soon after
# 0 	 209 	 1 	 1 	 Jamie Foxx absolutely IS Ray Charles
# 0 	 210 	 1 	 1 	 His performance is simply genius
# 0 	 211 	 1 	 1 	 He owns the film just as Spacek owned Coal Miner's Daughter and Quaid owned Great Balls of Fire
# 0 	 212 	 1 	 1 	 In fact it's hard to remember that the part of Ray Charles is being acted and not played by the man himself
# 0 	 213 	 1 	 1 	 Ray Charles is legendary
# 0 	 214 	 1 	 1 	 Ray Charles' life provided excellent biographical material for the film which goes well beyond being just another movie about a musician
# 0 	 215 	 1 	 1 	 Hitchcock is a great director
# 0 	 216 	 0 	 0 	 Ironically I mostly find his films a total waste of time to watch
# 0 	 217 	 1 	 1 	 Secondly Hitchcock pretty much perfected the thriller and chase movie
# 0 	 218 	 0 	 0 	 It's this pandering to the audience that sabotages most of his films
# 0 	 219 	 0 	 0 	 Hence the whole story lacks a certain energy
# 0 	 220 	 0 	 0 	 The plot simply rumbles on like a machine desperately depending on the addition of new scenes
# 0 	 221 	 0 	 0 	 There are the usual Hitchcock logic flaws
# 0 	 222 	 0 	 1 	 Mishima is extremely uninteresting
# 0 	 223 	 0 	 0 	 This is a chilly unremarkable movie about an author living/working in a chilly abstruse culture
# 0 	 224 	 0 	 0 	 The flat reenactments don't hold your attention because they are emotionally adrift and stagy
# 0 	 225 	 0 	 0 	 And the rest of it just sits there being awful  with soldiers singing songs about the masculinity they pledge themselves to hairsplitting about purity the admiration of swords etc
# 0 	 226 	 0 	 0 	 He can bore you to pieces and kill the momentum of a movie quicker than anyone else
# 0 	 227 	 0 	 0 	 Schrader has made a resume full of lousy amateurish films
# 0 	 228 	 1 	 1 	 When I first watched this movie in the 80s I loved it
# 0 	 229 	 1 	 1 	 I was totally fascinated by the music the dancing  everything
# 0 	 230 	 0 	 0 	 However I recently watched the whole thing again on DVD and I was completely struck by how extremely stupid the storyline was  how it contained holes inconsistencies and  frankly  a whole lot of crap  and how horrid the dancing was
# 0 	 231 	 0 	 0 	 I mean in a realistic world she would NEVER have gotten into that ballet repertory  The whole thing was quite pathetic
# 0 	 232 	 0 	 0 	 The character developments also lacked in depth
# 0 	 233 	 0 	 0 	 Woa talk about awful
# 0 	 234 	 0 	 0 	 Do not waste your time
# 0 	 235 	 0 	 0 	 It was just too horrible
# 0 	 236 	 0 	 0 	 The worst sappiest dialogue  I could go on and on
# 0 	 237 	 0 	 0 	 But what really made it unwatchable was the direction
# 0 	 238 	 0 	 0 	 The poor actors
# 0 	 239 	 0 	 0 	 You can't even tell if they have any talent because they not only have pathetic lines to speak but the director gave them no action
# 0 	 240 	 0 	 0 	 If you check the director's filmography on this site you will see why this film didn't have a chance
# 0 	 241 	 0 	 0 	 This would not even be good as a made for TV flick
# 0 	 242 	 1 	 1 	 If good intentions made a film great then this film might be one of the greatest films ever made
# 0 	 243 	 1 	 1 	 The film has great actors a master director a significant theme at least a would be significant theme undertone of fifties existential world weariness aerial scenes that ought to have thrilled both senses and imagination and characters about which one might deeply care
# 0 	 244 	 0 	 0 	 Regrettably the film fails
# 0 	 245 	 0 	 0 	 The movie lacks visual interest drama expression of feeling and celebration of the very patriotism that underlines the narrative
# 0 	 246 	 0 	 0 	 No actress has been worse used that June Allison in this movie
# 0 	 247 	 1 	 1 	 Yet I enjoy watching it
# 0 	 248 	 0 	 0 	 Unfortunately this is a bad movie that is just plain bad
# 0 	 249 	 0 	 0 	 Bad script bad direction and horrible acting make this one plain bad
# 0 	 250 	 0 	 0 	 The dialogue sucked
# 0 	 251 	 0 	 0 	 The cinematography if it can be called that sucked
# 0 	 252 	 0 	 0 	 The soundtrack sucked
# 0 	 253 	 0 	 0 	 The acting sucked
# 0 	 254 	 0 	 0 	 The concert sequences just sucked
# 0 	 255 	 1 	 1 	 That was nice
# 0 	 256 	 1 	 1 	 That was funny
# 0 	 257 	 1 	 1 	 It was so funny
# 0 	 258 	 0 	 0 	 Overall this movie was cheap trash
# 0 	 259 	 0 	 0 	 But this movie is not funny considering the ridiculousness of it
# 0 	 260 	 0 	 0 	 I came out of it feeling angry
# 0 	 261 	 1 	 1 	 SPOILERS  Whatever else can or can't be said about it SURFACE is superbly crafted
# 0 	 262 	 1 	 1 	 The cinematography is simply stunning to say the least and the fx are nothing if not state of the art
# 0 	 263 	 1 	 1 	 Conceptually the show offers a little bit of everything and for just about everybody parents kids fantasy and/or fx fans
# 0 	 264 	 1 	 1 	 And there wasn't a single sour note struck acting wise either some surprisingly solid casting here
# 0 	 265 	 1 	 1 	 All things considered a job very well done
# 0 	 266 	 1 	 1 	 Thanks good a movie like this was done and released
# 0 	 267 	 1 	 1 	 One of the best mexican movies ever  and one of the less understood even by mexican themselves no matter how identified the should have felt with it
# 0 	 268 	 1 	 1 	 It ranks highly as a great noir crime drama incredible performances by Belmondo and Lino Ventura
# 0 	 269 	 1 	 1 	 The attention given to every character and complex psychological portrayals detailing loyalty treachery love and hope are tremendous
# 0 	 270 	 1 	 1 	 It is an excellent drama an excellent thriller and an excellent film
# 0 	 271 	 1 	 1 	 Up there with the best of Melville
# 0 	 272 	 1 	 1 	 Everything about this film is simply incredible
# 0 	 273 	 1 	 1 	 You truly take this journey through the eyes and soul of a child
# 0 	 274 	 1 	 1 	 BLACK WATER is a thriller that manages to completely transcend it's limitations it's an indie flick by continually subverting expectations to emerge as an intense experience
# 0 	 275 	 1 	 1 	 The performances are real and gripping the crocdodile is extremely well done indeed if the Black Water website is to be believed that's because they used real crocs and the swamp location is fabulous
# 0 	 276 	 1 	 1 	 I thoroughly enjoyed it when Christopher Eccleston took control of the TARDIS and the continuation of the series
# 0 	 277 	 0 	 0 	 I'm not sure what he was trying to do with this film
# 0 	 278 	 0 	 0 	 If it was to turn my good day feeling into a night of disturbing memories than I guess he succeeded
# 0 	 279 	 1 	 0 	 There is a lot of beautiful places
# 0 	 280 	 0 	 0 	 It was forced like everything in this movie
# 0 	 281 	 0 	 0 	 Again lame
# 0 	 282 	 0 	 0 	 Here's where the movie really pi ed me off
# 0 	 283 	 0 	 0 	 And don't even get me started on the jerky camerawork
# 0 	 284 	 0 	 0 	 When I saw it in the theater I thought I was going to be sick
# 0 	 285 	 0 	 0 	 Summary The witticisms weren't witty
# 0 	 286 	 0 	 0 	 The plot  well I said I'd let that one go
# 0 	 287 	 0 	 0 	 The acting was bad
# 0 	 288 	 0 	 0 	 Really bad
# 0 	 289 	 0 	 0 	 Even Billy Bob couldn't rise above the script which was worse
# 0 	 290 	 0 	 0 	 Camerawork  again bad
# 0 	 291 	 0 	 0 	 Rating 1/10
# 0 	 292 	 1 	 1 	 An AMAZING finale to possibly the BEST trilogy of all time
# 0 	 293 	 1 	 1 	 Kieslowski never ceases to amaze me
# 0 	 294 	 1 	 1 	 He is one of my favourite directors and one of the most talented directors in the history of cinema
# 0 	 295 	 1 	 1 	 His use of the colours of the French flag in the three films was nothing short of incredible every shot every scene was like a work of art
# 0 	 296 	 1 	 0 	 Three of the most visually appealing movies i've ever seen
# 0 	 297 	 1 	 1 	 And his subtle connections between the three films are awesome
# 0 	 298 	 1 	 1 	 I have to mention this and it is a huge SPOILER i loved the ending how all the characters of the three films were the remaining survivors of the ferry disaster with Valentine and the young judge together and the old man watching it on her TV solidifying his happiness over the suffering which he dealt with for those many years
# 0 	 299 	 1 	 1 	 I couldn't think of a better way to end the film but a smile on my face great way to wrap up an amazing film and trilogy
# 0 	 300 	 1 	 1 	 I recommend this for EVERYONE who loves film movies anything  A Work of Art
# 0 	 301 	 1 	 1 	 10/10 for both the movie and trilogy
# 0 	 302 	 0 	 0 	 I literally vomited while watching this film
# 0 	 303 	 1 	 1 	 I think i was one of the people who found this another one of roth's pearls
# 0 	 304 	 1 	 1 	 his performance as awarded was stunning
# 0 	 305 	 1 	 1 	 the story which was told so eloquently by Francis ford Coppola 25 years earlier really unfolds gradually and leaves room for the characters to develop
# 0 	 306 	 1 	 1 	 In a most wonderful location lies a story of contrast
# 0 	 307 	 1 	 1 	 All in all a beautiful directed film from Nicola's roeg wih a sublime cast
# 0 	 308 	 0 	 0 	 I'm translating movies for a living and this is the first movie in my 5 year working experience that I found offensive to my intelligence
# 0 	 309 	 0 	 0 	 But when someone strives for greatness and poetry but delivers a muddled and often ridiculous story a bunch of disparate scenes pretentious dialogue  Then you get the worst kind of a movie that some other reviewer very accurately defined as pretentious crap
# 0 	 310 	 0 	 0 	 To those who find this movie intelligent or even masterful I can only say  it's your intelligence and your imagination you obviously used to try and make some sense of this pitiful attempt it's in our human nature to try and make sense of things
# 0 	 311 	 0 	 0 	 One more thing I can tolerate political incorrectness very well I'm all for artistic freedom and suspension of disbelief but the Slavic female character was just too much
# 0 	 312 	 1 	 1 	 This is such a fun and funny movie
# 0 	 313 	 1 	 1 	 Highly entertaining at all angles
# 0 	 314 	 1 	 1 	 It features an outlandish array of memorable psychotic but lovable nuts
# 0 	 315 	 1 	 1 	 So for our enjoyment we get to see them run around play games and be dangerous
# 0 	 316 	 1 	 1 	 It even has its sweet moments
# 0 	 317 	 1 	 1 	 The telephone repair man was really funny and his reactions to the nuts and bitchy boss were truly genuine
# 0 	 318 	 1 	 1 	 All the characters in this film are tremendously well played
# 0 	 319 	 1 	 1 	 And I really did find them funny
# 0 	 320 	 1 	 1 	 This is actually a very smart movie
# 0 	 321 	 1 	 1 	 There is a brilliant twist ending
# 0 	 322 	 1 	 1 	 I love it
# 0 	 323 	 1 	 1 	 The ending is so SO perfect  you'll shed a tear
# 0 	 324 	 1 	 1 	 I am so thrilled after seeing a movie like this
# 0 	 325 	 1 	 1 	 I will never forget it now
# 0 	 326 	 1 	 1 	 It is not just a cult  it is a cult CLASSIC
# 0 	 327 	 0 	 0 	 Which has more depth and character than the man underneath it
# 0 	 328 	 0 	 0 	 The Malta settings are as dry and as barren as the dialogue
# 0 	 329 	 0 	 0 	 This movie is terrible
# 0 	 330 	 0 	 0 	 The hockey scenes are terrible defensemen playing like they're 5 years old goalies diving at shots that are 10 feet wide of the net etc
# 0 	 331 	 0 	 0 	 For those that haven't seen it don't waste your time
# 0 	 332 	 0 	 0 	 To call this movie a drama is ridiculous
# 0 	 333 	 0 	 0 	 Started watching this but didn't believe in any of the characters
# 0 	 334 	 0 	 0 	 In particular the relationship between the bakery assistant and the waitress just didn't work for me at all
# 0 	 335 	 0 	 0 	 It was a very superficial movie and it gave me the feeling that I was watching play rather than a film
# 0 	 336 	 0 	 0 	 The characters were very 'stagey' and the storyline was a lot like a stage farce
# 0 	 337 	 0 	 0 	 By the time the pyromaniac waylaid the assistant I was bored and didn't care what happened next and so I switched off
# 0 	 338 	 0 	 0 	 Glad I didn't pay to see it
# 0 	 339 	 0 	 0 	 Didn't laugh or even smile once
# 0 	 340 	 0 	 0 	 But it wasn't anything at all just one big yawn
# 0 	 341 	 1 	 1 	 It is a really good show to watch
# 0 	 342 	 1 	 1 	 It is very educational for children 1 to 8 years old
# 0 	 343 	 1 	 1 	 Barney is definitely super DE duper
# 0 	 344 	 1 	 1 	 is pretty funny
# 0 	 345 	 1 	 1 	 Babie Bop is very cute
# 0 	 346 	 1 	 1 	 The kids are very cool too
# 0 	 347 	 0 	 0 	 But Storm Trooper is not even bad enough to make it to the list of wonderfully terrible movies
# 0 	 348 	 0 	 0 	 It's just lame
# 0 	 349 	 0 	 0 	 The guy who said he's had better dialogue with his potted plants has it right
# 0 	 350 	 0 	 0 	 Everything about this movie is stupid
# 0 	 351 	 0 	 0 	 Even if you love bad movies do not watch this movie
# 0 	 352 	 0 	 0 	 It is shameful
# 0 	 353 	 1 	 1 	 I would give this television series a 10 plus if i could
# 0 	 354 	 1 	 1 	 The writers were smack on and I think the best actors and actresses were a bonus to the show These characters were so real
# 0 	 355 	 1 	 1 	 I must say I have taped most of the episodes and i find myself watching them over and over again
# 0 	 356 	 1 	 1 	 Now you know why I gave it a 10
# 0 	 357 	 1 	 1 	 I don't know exactly what it is about this movie but we latched on to this endearing movie and it has become a special part of our family's memories
# 0 	 358 	 1 	 1 	 I totally and absolutely recommend this movie to anyone who likes good wholesome family movies because that is exactly what this is
# 0 	 359 	 1 	 1 	 The things that the four kids get themselves into is absolutely hilarious to watch
# 0 	 360 	 1 	 1 	 This is one of the best movies out there that shows such strong sibling bond for each other
# 0 	 361 	 1 	 1 	 Much more interesting more action more suspense and less of the unneeded controversy
# 0 	 362 	 1 	 1 	 Everything from acting to cinematography was solid
# 0 	 363 	 1 	 1 	 Definitely worth checking out
# 0 	 364 	 1 	 1 	 Damian is so talented and versatile in so many ways of writing and portraying different Characters on screen
# 0 	 365 	 1 	 1 	 This movie has a cutting edge to it
# 0 	 366 	 1 	 1 	 I am so pleased to know such a modern day genius is out there  letting is passion for Art drive him and taking us as an audience with him
# 0 	 367 	 0 	 0 	 The new characters weren't all that memorable and I found myself forgetting who was who
# 0 	 368 	 0 	 0 	 I felt as though her going to Ireland did absolutely nothing whatsoever
# 0 	 369 	 0 	 0 	 It didn't make me scared horrified or make me sympathetic towards the characters it was simply annoying
# 0 	 370 	 0 	 0 	 The jerky camera movements were also annoying
# 0 	 371 	 0 	 0 	 The plot was the same as pretty much every other cheap horror
# 0 	 372 	 0 	 0 	 There was a few pathetic attempts to give the characters some depth but it didn't really work into the rest of the plot
# 0 	 373 	 0 	 0 	 I guess it was supposed to be clever twist then shed some light on the situation but it was just stupid
# 0 	 374 	 0 	 0 	 If you see it you should probably just leave it on the shelf
# 0 	 375 	 1 	 1 	 Elias Koteas Jack Palance play good roles Angelina is hot and gets naked Billy Drago appears in this and is cool as usual  a cameo by Sven ole Thorsen helps make this a very enjoyable movie with good acting and a decent budget
# 0 	 376 	 1 	 1 	 This was such an awesome movie that i bought it off of Ebay
# 0 	 377 	 1 	 1 	 I really loved the story line and the poler bear was kinda cute But if anyone has a question about Fort Steele just ask away
# 0 	 378 	 0 	 0 	 This totally UNfunny movie is so over the top and pathetic and unrealistic that throughout the whole 90 minutes of utter torture I probably looked at my watch about 70000 times
# 0 	 379 	 0 	 0 	 Lucy Bell is so much higher than this crap and for her to sink this low is quite depressing
# 0 	 380 	 0 	 0 	 All this movie does is make you sick watching all these slackers make excuses for their stupid actions for 90 minutes
# 0 	 381 	 0 	 0 	 God and I can never get that 90 minutes back
# 0 	 382 	 1 	 1 	 I think the most wonderful parts literally full of wonder are the excerpts from his works
# 0 	 383 	 1 	 1 	 The sets especially designed to work with the camera are amazing  stylized beautiful and effective
# 0 	 384 	 1 	 1 	 They could be used as exemplars for any set designer
# 0 	 385 	 1 	 1 	 The stories were powerful explorations of the nature of man and of art
# 0 	 386 	 1 	 1 	 After watching this film I wanted to learn more about the works of this artist
# 0 	 387 	 1 	 1 	 I highly recommend this movie for anyone interested in art poetry theater politics or Japanese history
# 0 	 388 	 1 	 1 	 Here in The Wind and the Lion we see a wonderful rendering of America's own Imperial age
# 0 	 389 	 1 	 1 	 What makes this story different are the terrific production values  faultless photography composition and editing  the terrific casting  the underappreciated Brian Keith playing a bully Teddy  and vivid history
# 0 	 390 	 1 	 1 	 Though The Wind and the Lion is told largely through the eyes of the son every member of the family can identify with one of the characters whether it be Sean Connery's noble brigand Candace Bergen's feisty heroine John Huston's wily John Hay or Steve Kanaly's spiffy radiant ruthless can do lieutenant Roosevelt's Big Stick
# 0 	 391 	 1 	 1 	 This is high adventure at its best
# 0 	 392 	 1 	 1 	 I think it was Robert Ryans best film because he portrayed someone like my father and he was a schizophrenic in real life my father although he never murdered anyone but was affected more so during the second world war which made him worse
# 0 	 393 	 1 	 1 	 Having to humour him just to get by and get through the day was so apt
# 0 	 394 	 1 	 1 	 My mother and brother had to do this When I saw Robert Ryan portraying this type of man it was a very good imitation of this type of individual and I was impressed
# 0 	 395 	 0 	 0 	 Almost all of the songs in Cover Girl are old fashioned and not very tuneful
# 0 	 396 	 0 	 0 	 The most annoying thing about 'Cover Girl' is the way in which Rita Hayworth is put up on a pedestal
# 0 	 397 	 0 	 0 	 Unfortunately 'Cover Girl' is an example of how Hollywood used to exploit women for financial gain
# 0 	 398 	 1 	 1 	 Non linear narration thus many flashbacks and every part are articulated quite well
# 0 	 399 	 1 	 1 	 The good cinematography also makes her and Monica Bellucci look very beautiful
# 0 	 400 	 1 	 1 	 A good commentary of today's love and undoubtedly a film worth seeing
# 0 	 401 	 1 	 1 	 For people who are first timers in film making I think they did an excellent job
# 0 	 402 	 1 	 1 	 It was very popular when I was in the cinema a good house and very good reactions and plenty of laughs
# 0 	 403 	 1 	 1 	 It's a feel good film and that's how I felt when I came out of the cinema
# 0 	 404 	 1 	 1 	 It has northern humour and positive about the community it represents
# 0 	 405 	 1 	 1 	 I rather enjoyed it
# 0 	 406 	 1 	 1 	 I liked it
# 0 	 407 	 0 	 0 	 I couldn't take them seriously
# 0 	 408 	 1 	 1 	 It really created a unique feeling though
# 0 	 409 	 1 	 1 	 Vivian Schilling did an excellent job with the script
# 0 	 410 	 1 	 1 	 A world better than 95 of the garbage in the theatres today
# 0 	 411 	 1 	 1 	 Her role was played well
# 0 	 412 	 1 	 1 	 Not too screamy not to masculine but just right
# 0 	 413 	 1 	 1 	 The camera really likes her in this movie
# 0 	 414 	 1 	 1 	 I would have casted her in that role after ready the script
# 0 	 415 	 1 	 1 	 As a European the movie is a nice throwback to my time as a student in the 1980's and the experiences I had living abroad and interacting with other nationalities although the circumstances were slightly different
# 0 	 416 	 0 	 0 	 I am a fan of his   This movie sucked really bad
# 0 	 417 	 0 	 0 	 Even worse than Ticker
# 0 	 418 	 0 	 0 	 That movie was bad
# 0 	 419 	 0 	 0 	 Only like 3 or 4 buildings used a couple of locations MAYBE  poor hummh
# 0 	 420 	 0 	 0 	 It just blew
# 0 	 421 	 1 	 1 	 This movie is excellent Angel is beautiful and Scamp is adorable His little yelps when hes scared and the funniest parts are when Scamp is caught under the curtain and when Angel and Scamp are singing 'Ive Never Had This Feeling Before' I totally recommend this movie its coming out on special edition on June 20 The cover has scamp on a garbage can and Angel underneath the lid
# 0 	 422 	 1 	 1 	 I just cant explain this movie more than romantic charming hilarious and adorable The junkyard scenes are funny all the junkyard dogs have something special Too funny i laughed kids will LOVE it Buy it when it comes out it has new features
# 0 	 423 	 0 	 0 	 Now we were chosen to be tortured with this disgusting piece of blatant American propaganda
# 0 	 424 	 0 	 0 	 This show is made for Americans  it is too stupid and full with hatred and clich s to be admitted elsewhere
# 0 	 425 	 0 	 0 	 Almost everyone involved must be return to school acting is utterly predictable and bad script is pile of garbage all round
# 0 	 426 	 0 	 0 	 I wish I could enter negative values admins
# 0 	 427 	 0 	 0 	 The sets are so bad they wouldn't look out of place on a Thunderbirds episode
# 0 	 428 	 0 	 0 	 The use of slow motion needlessly repeats itself throughout the movie but is well backed up by bad acting and bad is a kind word here  no continuity scenes that are thrown in for no reason whatsoever vehicles that looked like they were made from a Corn Flakes box and a directorial style that bordered on stupidity
# 0 	 429 	 0 	 0 	 Oh yeah and the storyline was pathetic too
# 0 	 430 	 0 	 0 	 I hate writing bad reviews about films  especially those in which I really like the star  but this film is so bad I don't believe for one second that anyone could have been proud of it
# 0 	 431 	 0 	 0 	 I am not a filmmaker nor am I a director but I would hide my head in the sand if I'd spent whatever amount of money and time on this movie
# 0 	 432 	 0 	 0 	 In short  this was a monumental waste of time and energy and I would not recommend anyone to EVER see this film
# 0 	 433 	 0 	 0 	 It came free with a DVD player I bought but I still turned the thing off halfway through because I was embarrassed for Howell
# 0 	 434 	 0 	 0 	 1/10  and only because there is no setting for 0/10
# 0 	 435 	 1 	 1 	 An interesting premise and Billy Drago is always good as a dangerous nut bag side note I'd love to see Drago Stephen McHattie and Lance Hendrikson in a flick together talk about raging cheekbones
# 0 	 436 	 1 	 1 	 The soundtrack wasn't terrible either
# 0 	 437 	 0 	 0 	 But the acting even that of such professionals as Drago and Debbie Rochon was terrible the directing worse perhaps contributory to the former  the dialog chimp like and the camera work barely tolerable
# 0 	 438 	 1 	 1 	 Still it was the SETS that got a big 10 on my oy vey scale
# 0 	 439 	 0 	 0 	 Yes I am simplifying things here for the sake of brevity for this really is at the core of the problems with this film  it has too much going on without any real fulfilling explanation
# 0 	 440 	 1 	 1 	 Both do good jobs and are quite amusing
# 0 	 441 	 0 	 0 	 But the convoluted plot just didn't convince me and much of the film was watched with a weird questioning glance
# 0 	 442 	 0 	 0 	 I let my girlfriend talk me into seeing this  bad idea we both hated it
# 0 	 443 	 1 	 0 	 The last 15 minutes of movie are also not bad as well
# 0 	 444 	 0 	 0 	 Bela Lugosi was totally extraneous intoning odd lines
# 0 	 445 	 0 	 0 	 The acting was decidely wooden though no worse than a period Universal B movie
# 0 	 446 	 1 	 1 	 I like Armand Assante  my cable company's summary sounded interesting so I watched it twice already and probably will again
# 0 	 447 	 1 	 1 	 I believe the screenwriter did a good job of tying up the loose ends
# 0 	 448 	 1 	 1 	 My 8/10 score is mostly for the plot
# 0 	 449 	 1 	 1 	 I won't say any more  I don't like spoilers so I don't want to be one but I believe this film is worth your time
# 0 	 450 	 0 	 0 	 Wow what a bad film
# 0 	 451 	 0 	 0 	 Not frightening in the least and barely comprehensible
# 0 	 452 	 0 	 0 	 The plot doesn't hang together at all and the acting is absolutely appalling
# 0 	 453 	 0 	 0 	 Not even good for camp value
# 0 	 454 	 0 	 0 	 I wasn't expecting Oscar material but this
# 0 	 455 	 0 	 0 	 You'd have to have the IQ of particularly stupid mollusk not to see that one coming
# 0 	 456 	 0 	 0 	 This film and I use that word loosely is an insult to the movie going public
# 0 	 457 	 0 	 0 	 If only someone involved with it knew how to string together narrative
# 0 	 458 	 0 	 0 	 This gets a 1/10 simply because there's nothing lower
# 0 	 459 	 0 	 0 	 This is one I did not have but I watched it recently on Fox Movie Channel and was very disappointed
# 0 	 460 	 0 	 0 	 I know he was a contract player with little control over his scripts but the acting was as bad as the script
# 0 	 461 	 0 	 0 	 Victor McLaglen was even bad and Brian DonLevy was almost unrecognizable
# 0 	 462 	 0 	 0 	 Considering the relations off screen between Taylor and Stanwyck it was surprising how little chemistry there was on screen between the two of them
# 0 	 463 	 0 	 0 	 But the premise of the film was so ridiculous that the President of the U S
# 0 	 464 	 0 	 0 	 The death row scenes were entirely unmoving
# 0 	 465 	 0 	 0 	 The only thing worse than Taylor's acting was Stanwyck's singing
# 0 	 466 	 0 	 0 	 Whatever the producer was going for he missed entirely
# 0 	 467 	 1 	 1 	 I was deeply impressed with the character he played
# 0 	 468 	 1 	 1 	 I knew when I saw the film that more great things were to come from this gifted actor
# 0 	 469 	 0 	 0 	 A cheap and cheerless heist movie with poor characterisation lots of underbite style stoic emoting think Chow Yun Fat in A Better Tomorrow and some cheesy clich s thrown into an abandoned factory ready for a few poorly executed flying judo rolls a la John Woo
# 0 	 470 	 0 	 0 	 Even the squibs look awful
# 0 	 471 	 0 	 0 	 At no point in the proceedings does it look remotely like America
# 0 	 472 	 0 	 0 	 The plot such as it is is so derivative and predictable that the ending is like a mercy killing
# 0 	 473 	 0 	 0 	 The awful dialogue and hopeless overacting by everyone who gets shot top off a real waste of space and time
# 0 	 474 	 0 	 0 	 I was very uneasy with how bad this movie was but not scared at all
# 0 	 475 	 0 	 0 	 The dialogue is composed of things that make little sense
# 0 	 476 	 0 	 0 	 About 30 minutes of footage is wasted to show mediocre elderly actors awkwardly babbling overwrought pseudo Satanic gibberish corny enough to make a teen Goth blush almost always in Olde English and sometimes in Latin that may or may not be made up words
# 0 	 477 	 0 	 0 	 The directing is sloppy at best
# 0 	 478 	 0 	 0 	 Hackneyed writing certainly but made even worse by the bad directing
# 0 	 479 	 0 	 0 	 Of course the acting is blah
# 0 	 480 	 0 	 0 	 The acting by the whole cast could be put on a scale and balanced perfectly between overacting and underacting
# 0 	 481 	 0 	 0 	 And FINALLY after all that we get to an ending that would've been great had it been handled by competent people and not Jerry Falwell
# 0 	 482 	 1 	 1 	 I loved this movie it was a great portrayal of a family who had it's share of ups and down but in the end they knew that special love they had for each other
# 0 	 483 	 1 	 1 	 I have seen many movies starring Jaclyn Smith but my god this was one of her best though it came out 12 years ago
# 0 	 484 	 1 	 1 	 This movie contained an all star cast and what I loved the most was that it opened my eyes to see other actors who I haven't seen before
# 0 	 485 	 1 	 1 	 This movie was kind of long in length but I enjoyed every minute of it
# 0 	 486 	 1 	 1 	 Overall I rate this movie a 10 out of a 1 10 scale
# 0 	 487 	 1 	 1 	 Lifetime does not air it enough so if anyone knows what store sells it let me know because this is a must have
# 0 	 488 	 0 	 0 	 I particularly remember my senses being assaulted by strident cords of music that would blare out with very little warning and even less meaning
# 0 	 489 	 0 	 0 	 It is just the sort of pap that is screened in the afternoon to punish the unemployed for not having jobs
# 0 	 490 	 1 	 1 	 Totally different with loads of understatement and black comedy this is a film few get to see but those who do will remember it
# 0 	 491 	 1 	 1 	 This movie creates its own universe and is fascinating in every way
# 0 	 492 	 1 	 0 	 But this movie really got to me
# 0 	 493 	 1 	 1 	 See it
# 0 	 494 	 1 	 1 	 I really hope the team behind this movie makes more movies and that they will continue to do so in their own some kinda weird style
# 0 	 495 	 1 	 1 	 And I forgot The Casting here i superb with Trond Fausa Aurv g being perfect in the role as the Bothersome Man who doesn't understand where he is what he is doing and why
# 0 	 496 	 1 	 1 	 This movie is a good and humorous comment on life in 2006
# 0 	 497 	 1 	 1 	 I found this move beautiful enjoyable and uplifting
# 0 	 498 	 1 	 1 	 Initially the local sites in the film which was filmed here in Buffalo intrigued me
# 0 	 499 	 1 	 1 	 Later I found myself lost in the power of the film
# 0 	 500 	 1 	 1 	 The entire audience applauded at the conclusion of the film
# 0 	 501 	 1 	 1 	 I left the theater with a lilt in my step joy in my heart and hope for the human race
# 0 	 502 	 1 	 1 	 Duris has a wholesome appearance and gives a fine performance
# 0 	 503 	 1 	 1 	 The rest of the cast also play well
# 0 	 504 	 1 	 1 	 Cinematography noteworthy including fine views of Barcelona and its famed Gaudi towers
# 0 	 505 	 0 	 0 	 About ten minutes into this film I started having second thoughts
# 0 	 506 	 0 	 0 	 About half way through this film I started to dislike it
# 0 	 507 	 0 	 0 	 By the time the film ended I not only disliked it I despised it
# 0 	 508 	 0 	 0 	 What this film lacks is a convincing script
# 0 	 509 	 0 	 0 	 The script looks as if only a rough draft was written and shooting began before a finished script was completed
# ...
# 0 	 834 	 0 	 0 	 Very disappointed and wondered how it could be in the Oscar shortlist
# 0 	 835 	 0 	 0 	 It's very slow
# 0 	 836 	 0 	 0 	 Lot of holes in the plot there's nothing about how he became the emperor nothing about where he spend 20 years between his childhood and mature age
# 0 	 837 	 0 	 0 	 Don't waste your time
# 0 	 838 	 0 	 0 	 End of Days is one of the worst big budget action movies I've ever seen
# 0 	 839 	 0 	 0 	 He surely doesn't know how to make a coherent action movie from the screenwriter of Air Force One who was only obliged to write the script just for a big sum of money
# 0 	 840 	 0 	 0 	 This was one of the worst films i have ever seen
# 0 	 841 	 0 	 0 	 I'm still trying to get over how bad it was
# 0 	 842 	 1 	 1 	 This movie is possibly one of the most creative works of horror ever
# 0 	 843 	 1 	 1 	 It has everything you could want  suspense drama comedy confusing subplots native americans brain eating  If you're looking for the be all end all of brainsucking movies look no further
# 0 	 844 	 1 	 1 	 With great sound effects and impressive special effects I can't recommend this movie enough
# 0 	 845 	 1 	 1 	 Call me a nut but I think this is one of the best movies ever
# 0 	 846 	 1 	 1 	 Great character actors Telly Savalas and Peter Boyle
# 0 	 847 	 0 	 0 	 1 hour 54 minutes of sheer tedium melodrama and horrible acting a mess of a script and a sinking feeling of GOOD LORD WHAT WERE THEY THINKING
# 0 	 848 	 0 	 0 	 Lots of holes in the script
# 0 	 849 	 0 	 0 	 It's like a bad two hour TV movie
# 0 	 850 	 0 	 0 	 Now imagine that every single one of those decisions was made wrong
# 0 	 851 	 0 	 0 	 The dialogue is atrocious
# 0 	 852 	 0 	 0 	 The acting is beyond abysmal
# 0 	 853 	 0 	 0 	 Everything stinks
# 0 	 854 	 0 	 0 	 Trouble is the writing and directing make it impossible to establish those things that make a movie watchable like character story theme and so on
# 0 	 855 	 0 	 0 	 Worse there's an incredibly weak sub plot thrown in that follows a little band of latter day Mansonites as they go after a reporter who's working on a story on the anniversary of the killings
# 0 	 856 	 0 	 0 	 It's dumb and pointless and a complete waste of time
# 0 	 857 	 0 	 0 	 In short don't bother with this movie
# 0 	 858 	 1 	 1 	 I won't spoil it but the ending in pretty amazing
# 0 	 859 	 1 	 1 	 The best scene in the movie is at the end but I won't spoil it
# 0 	 860 	 1 	 1 	 If there was ever an indication of a writer and a director's ability to meld two highly volatile temperaments into a seamless union of creativity then this is it
# 0 	 861 	 1 	 1 	 The result is a powerhouse achievement made more timely now perhaps because of our culture's disturbing fascination with celebrity and it's distorted interpretations of fame
# 0 	 862 	 1 	 1 	 A film not easily forgotten
# 0 	 863 	 1 	 1 	 But Kevin Spacey is an excellent verbal tsunami as Buddy Ackerman  and totally believable because he is a great actor
# 0 	 864 	 1 	 1 	 The scripting of the subtle comedy is unmatched by any movie in recent years
# 0 	 865 	 1 	 1 	 The characters are interesting even if a bit predictable
# 0 	 866 	 1 	 1 	 Highly recommended for all ages although the younger set will probably not appreciate some of the more subtle references they will certainly appreciate one galley scene in particular
# 0 	 867 	 1 	 1 	 Great movie
# 0 	 868 	 0 	 0 	 Also the story and acting were weak
# 0 	 869 	 0 	 0 	 At around 4 pm I bought it at around 8pm I started to watch at around 8 15pm I fast forwarded the remaining film to see if there was anything left watchable for a human being with a brain  but there wasn't
# 0 	 870 	 0 	 0 	 Either way it sucks
# 0 	 871 	 0 	 0 	 The script is horrendously stupid
# 0 	 872 	 0 	 0 	 The story starts too fast with absolutely no suspense or build up in the slightest
# 0 	 873 	 0 	 0 	 Everything Captain Howdy says is either laughable or just plain stupid
# 0 	 874 	 0 	 0 	 What the hell kind of crap is that
# 0 	 875 	 0 	 0 	 Then there's the plot holes
# 0 	 876 	 0 	 0 	 You could drive a semi truck into these holes
# 0 	 877 	 1 	 1 	 Linda Cardellini is the only thing good in this film
# 0 	 878 	 1 	 1 	 She's poised and amazing
# 0 	 879 	 0 	 0 	 Dee Snider just plain sucks
# 0 	 880 	 0 	 0 	 He can't act one of the least scary villains I have ever seen  he can't write did he write this damn movie in his sleep
# 0 	 881 	 0 	 0 	 I was bored throughout the whole damn thing
# 0 	 882 	 0 	 0 	 The acting sucks the music sucks the script sucks the pacing sucks the special FX suck the directing sucks  basically this movie sucks
# 0 	 883 	 0 	 0 	 This film tries to be a serious and sophisticated thriller/horror flick and it fails miserably
# 0 	 884 	 0 	 0 	 This is probably one of the least effective and utterly unoriginal films I have ever seen in my entire life
# 0 	 885 	 0 	 0 	 A piece of cinematic garbage captured on celluloid
# 0 	 886 	 0 	 0 	 Avoid at any and all costs
# 0 	 887 	 0 	 0 	 At any rate this film stinks its not funny and Fulci should have stayed with giallo and supernatural zombie movies
# 0 	 888 	 0 	 0 	 Avoid this film at all costs
# 0 	 889 	 0 	 0 	 I don't know what happened in Season Five what a mess
# 0 	 890 	 0 	 0 	 The only consistent thread holding the series together were the amazing performances of Leni Parker and Anita LaSelva as the two Taelons in quiet idealogical conflict
# 0 	 891 	 0 	 0 	 Now this is a movie I really dislike
# 0 	 892 	 0 	 0 	 It's one of the most boring Horror movies from the 90's mainly because it starts slow and centers in a boring atmosphere
# 0 	 893 	 0 	 0 	 The puppets look really cheesy  not in a good way like in the Puppet Master 80's flicks
# 0 	 894 	 0 	 0 	 The story is lame not interesting and NEVER really explains the sinister origins of the puppets
# 0 	 895 	 0 	 0 	 There aren't death scenes like in previous movies and the f/x are terrible
# 0 	 896 	 0 	 0 	 I felt asleep the first time I watched it so I can recommend it for insomniacs
# 0 	 897 	 1 	 1 	 The fact is this film is a wonderful heartwarming tale about two people chasing their dreams
# 0 	 898 	 1 	 1 	 The best part about Nurse Betty is it's unpredictability
# 0 	 899 	 1 	 1 	 Director Neil LaBute uses brutal violence to seperate dreams from reality and along with the touching drama and hilarious comedy you can never tell what is going to happen next
# 0 	 900 	 0 	 0 	 Otherwise don't even waste your time on this
# 0 	 901 	 0 	 0 	 This one just fails to create any real suspense
# 0 	 902 	 0 	 0 	 As for the killer don't expect anything original or even remotely frightening
# 0 	 903 	 1 	 1 	 There is however some pretty good acting at least for this type of film
# 0 	 904 	 0 	 0 	 I'm so sorry but I really can't recommend it to anyone
# 0 	 905 	 0 	 0 	 One of the most boring pointless movies I have ever seen
# 0 	 906 	 0 	 0 	 The secondary plot line is incomprehensible and its relation to the primary plot line is mystifying
# 0 	 907 	 0 	 0 	 Hated it
# 0 	 908 	 0 	 0 	 This is one of the worst Sandra Bullock movie since Speed 2 But not quite that bad
# 0 	 909 	 0 	 0 	 I don't understand how this garbage got on the shelves of the movie store it's not even a real movie
# 0 	 910 	 0 	 0 	 I highly doubt that anyone could ever like this trash
# 0 	 911 	 0 	 0 	 This is not movie making
# 0 	 912 	 0 	 0 	 The acting is like watching wooden puppets moving around and reading from a book that's how bad it is
# 0 	 913 	 0 	 0 	 So I am here to warn you DO NOT RENT THIS MOVIE it is the dumbest thing you have never seen
# 0 	 914 	 1 	 1 	 I saw this short film on HBO the other day and absolutely loved it
# 0 	 915 	 1 	 1 	 I didn't realize how wonderful the short really is until the last two scenes
# 0 	 916 	 1 	 1 	 Excellent short film
# 0 	 917 	 1 	 1 	 Hopefully the director James Cox can turn the short into a feature length film with the same cast or win us over with a whole new film
# 0 	 918 	 0 	 0 	 I agree with Jessica this movie is pretty bad
# 0 	 919 	 0 	 0 	 Characters are one dimensional even the good guys and especially the bad guys
# 0 	 920 	 0 	 0 	 The story line is totally predictable
# 0 	 921 	 1 	 1 	 Not much dialogue not much music the whole film was shot as elaborately and aesthetically like a sculpture
# 0 	 922 	 0 	 0 	 I've seen soap operas more intelligent than this movie
# 0 	 923 	 0 	 0 	 Bad characters bad story and bad acting
# 0 	 924 	 0 	 0 	 Really awful
# 0 	 925 	 0 	 0 	 Not easy to watch
# 0 	 926 	 1 	 1 	 Funny clever hip  just like Pray's previous film Hype
# 0 	 927 	 1 	 1 	 It was a long time that i didn't see a so charismatic actor on screen
# 0 	 928 	 1 	 1 	 Paolo Sorrentino has written a wonderful story about loneliness and Tony has built one of the most unforgettable characters seen in movies in recent years
# 0 	 929 	 1 	 1 	 The movie is not completely perfect but 'Titta Di Girolamo' will stay with you for a long time after the vision of the movie
# 0 	 930 	 1 	 1 	 I rate this movie 9/10
# 0 	 931 	 1 	 1 	 I do not know if this was Emilio Estevez's directorial debut but the pacing the interplay and development of the characters as well as some clever camera work surrounding the character Estevez plays all suggest a natural eye
# 0 	 932 	 1 	 1 	 The interplay between Martin and Emilio contains the same wonderful chemistry we saw in Wall Street with Martin and Charlie
# 0 	 933 	 1 	 1 	 Kathy Bates is wonderful in her characters subtle desperation and escapism a variation on her character in At Play In The Fields Of The Lord
# 0 	 934 	 1 	 1 	 For readers who have already seen one of Miyazaki's films he is still in top form and made another worthwhile experience
# 0 	 935 	 1 	 1 	 It never condescends all the characters have good genuine hearts and believable problems
# 0 	 936 	 1 	 1 	 The two main characters may be two of the most believable children I ever saw put on screen
# 0 	 937 	 1 	 1 	 They are so easy to love but even more easy to identify with
# 0 	 938 	 1 	 1 	 This movie is great especially if you enjoy visual arts
# 0 	 939 	 1 	 1 	 The scenery that the two daughters paint and photograph are beautiful
# 0 	 940 	 1 	 1 	 The story is also both funny and poignant at times
# 0 	 941 	 1 	 1 	 People who like European films and art movies will like this movie
# 0 	 942 	 1 	 1 	 This is truly an art movie it actually has a lot of art in it
# 0 	 943 	 1 	 1 	 Go rent it
# 0 	 944 	 1 	 1 	 However after finally watching this film I realized that not only had I had a closed mind to the brilliance it depicts I also found myself watching it over and over again
# 0 	 945 	 1 	 1 	 It's the one movie that never ceases to interest me simply because it keeps me alert as I try to attempt to decipher it's meanings
# 0 	 946 	 1 	 1 	 Brilliance indeed
# 0 	 947 	 1 	 1 	 But if you liked movies like The Matrix and better yet their sequels I think you'll appreciate the thought provoking mindblowing experience this film will give you
# 0 	 948 	 1 	 1 	 Think of the film being like a dream
# 0 	 949 	 1 	 1 	 Simply beautiful
# 0 	 950 	 1 	 1 	 Both Rickman and Stowe play their roles to the hilt in this tale of a childrens' book writer who  maybe  has written a subversive tract
# 0 	 951 	 1 	 1 	 It's a gloriously fun fast paced and fairly accurate portrayal of the night of a raver
# 0 	 952 	 1 	 1 	 It presents a idyllic yet serious portrayal of the ups and downs of the characters lives
# 0 	 953 	 0 	 0 	 Just whatever you do avoid Groove as its the antithesis of all that is good about Human Traffic
# 0 	 954 	 0 	 0 	 It's too bad that everyone else involved didn't share Crowe's level of dedication to quality for if they did we'd have a far better film on our hands than this sub par mess
# 0 	 955 	 0 	 0 	 The movie seemed a little slow at first
# 0 	 956 	 1 	 1 	 But it picked up speed and got right to the point
# 0 	 957 	 1 	 1 	 It showed exactly how the government and the scientist argued for humanity and the reasons of the gadget
# 0 	 958 	 1 	 1 	 I enjoyed it
# 0 	 959 	 1 	 1 	 I have recommended it to friends
# 0 	 960 	 1 	 1 	 I was particularly pleased with the acting ability of Dwight Schultz
# 0 	 961 	 1 	 1 	 Both actors truly understand and become their particular character delivering a convincing sincere performance
# 0 	 962 	 1 	 1 	 Their on screen chemistry critical to the entire film is genuine
# 0 	 963 	 1 	 1 	 The film's dialogue is natural real to life
# 0 	 964 	 1 	 1 	 The writer Gorman Bechard undoubtedly did his homework because all references are industry and character age appropriate
# 0 	 965 	 1 	 1 	 The incredible soundtrack truly captures the essence of the film
# 0 	 966 	 1 	 1 	 Each track commands sentiment actually contributing to the scenes and characters
# 0 	 967 	 1 	 1 	 Definitely worth seeing it's the sort of thought provoking film that forces you to question your own threshold of loneliness
# 0 	 968 	 1 	 1 	 Hayao Miyazaki's latest and eighth film for Studio Ghibili Gake No Ue No Ponyo Ponyo on the Cliff by the Sea is a wonderfully fun and imaginative look at childhood
# 0 	 969 	 1 	 1 	 At a time when it seems that film animation has been dominated by Disney/Pixar's CGI masterpieces it is both refreshing and comforting to know that Miyazaki is still relying on traditional hand drawn animation to tell his charming and enchanting stories
# 0 	 970 	 1 	 1 	 Enough can not be said of the remarkable animation in this film
# 0 	 971 	 1 	 1 	 The art style has the appearance of crayon/pencil drawings and is wonderfully colorful and fanciful
# 0 	 972 	 0 	 0 	 If you act in such a film you should be glad that you're gonna drift away from earth as far as possible
# 0 	 973 	 0 	 0 	 This one wants to surf on the small wave of space movies in 1998 Deep Impact and Armageddon  and this one fails everywhere
# 0 	 974 	 0 	 0 	 If you haven't choked in your own vomit by the end by all the cheap drama and worthless dialogue you've must have bored yourself to death with this waste of time
# 0 	 975 	 1 	 1 	 Still it makes up for all of this with a super ending that depicts a great sea vessel being taken out by the mighty frost
# 0 	 976 	 1 	 1 	 Just consider the excellent story solid acting and look of the film as added bonuses
# 0 	 977 	 0 	 0 	 Instead we got a bore fest about a whiny spoiled brat babysitting
# 0 	 978 	 1 	 1 	 Then I watched it again two Sundays ago March 20th 2005 and I began to really enjoy it and this time I taped the entire thing
# 0 	 979 	 1 	 1 	 It is a very well acted and done TV Movie
# 0 	 980 	 1 	 1 	 Judith Light is one of my favorite actresses and I think she does a superb job in this film
# 0 	 981 	 1 	 1 	 I keep watching it over and over
# 0 	 982 	 1 	 1 	 It's a sad movie but very good
# 0 	 983 	 1 	 1 	 If you have not seen this movie I definitely recommend it
# 0 	 984 	 1 	 1 	 She is as lovely as usual this cutie
# 0 	 985 	 1 	 1 	 Still it's quite interesting and entertaining to follow
# 0 	 986 	 1 	 1 	 Recommend with confidence
# 0 	 987 	 1 	 1 	 This movie is well balanced with comedy and drama and I thoroughly enjoyed myself
# 0 	 988 	 1 	 1 	 It was a riot to see Hugo Weaving play a sex obsessed gay real estate salesman who uses his clients' houses for his trysts with the flaming Darren Tom Hollander
# 0 	 989 	 1 	 0 	 Anyway the plot flowed smoothly and the male bonding scenes were a hoot
# 0 	 990 	 1 	 1 	 The opening sequence of this gem is a classic and the cat n mouse games that follow are a delight to watch
# 0 	 991 	 1 	 1 	 Fans of the genre will be in heaven
# 0 	 992 	 1 	 1 	 Lange had become a great actress
# 0 	 993 	 1 	 1 	 It looked like a wonderful story
# 0 	 994 	 0 	 0 	 I never walked out of a movie faster
# 0 	 995 	 0 	 0 	 I just got bored watching Jessice Lange take her clothes off
# 0 	 996 	 0 	 0 	 Unfortunately any virtue in this film's production work was lost on a regrettable script
# 0 	 997 	 0 	 0 	 In a word it is embarrassing
# 0 	 998 	 0 	 0 	 Exceptionally bad
# 0 	 999 	 0 	 0 	 All in all its an insult to one's intelligence and a huge waste of money

# %% [markdown]
# # Summary
# ---

# %% [markdown]
# - Given the same features, the `Gaussian Naive Bayes` classifier appears to the be the _most accurate_ at 99.9% correct prediction, more so than Complement, MultiNomial, and Bernoulli classifiers.
# - Furthermore, removing neutral sentiment keywords has no impact on the Gaussian NB classifier's accuracy, though it is quite hard to improve on 999/1000 correct prediction.
#  - For Complement and MultiNomial classifiers, removing neutral keywrods improved accuracy by 0.2%.
#  - For Bernoulli classifier, removing neutral keywords improved accuracy by 0.9%.
# - The Bernoulli classifier accuracy was improved 0.8% first by grouping similar keywords (Brilliance + Brilliant, 8/10 + 9/10 + 10/10)
